# %%
import pandas as pd
import numpy as np
import scanpy as sc
from sklearn.linear_model import LinearRegression
from collections import Counter
from scipy import stats
from tqdm import tqdm
import matplotlib.pyplot as plt
# Out:
# Bad key text.latex.preview in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 466 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 477 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 479 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
neuron_age_data = sc.read_h5ad("/Users/charlotte/Desktop/Pellegrini_Lab/Aging/SVC/SVC_neuron.h5ad")

# %%
neuron_age_data.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm37381', 'Rp1', 'Sox17', 'Gm37323', 'Mrpl15',
#        'Lypla1', 'Gm37988', 'Tcea1',
#        ...
#        'AC125149.1', 'AC125149.2', 'AC125149.4', 'AC234645.1', 'AC168977.2',
#        'AC168977.1', 'AC149090.1', 'CAAA01118383.1', 'Vmn2r122',
#        'CAAA01147332.1'],
#       dtype='object', length=31053)

# %%
celltypes = pd.DataFrame(neuron_age_data.obs["Celltype.LowRes"])

# %%
Counter(neuron_age_data.obs["Celltype.LowRes"])
# Out:
# Counter({'Oligodendro': 5943,
#          'Endothelial': 939,
#          'Microglia': 3844,
#          'Macrophage': 268,
#          'Astrocyte_qNSC': 2756,
#          'aNSC_NPC': 2396,
#          'Mural': 434,
#          'Ependymal': 107,
#          'Neuroblast': 4341,
#          'OPC': 274,
#          'Neuron': 156})

# %%
celltype_dict = {}
for celltype in Counter(neuron_age_data.obs["Celltype.LowRes"]):
    celltype_dict[celltype] = list(neuron_age_data.obs[neuron_age_data.obs["Celltype.LowRes"] == celltype].index)

# %%
neuron_age_data.obs
# Out:
#                      orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# barcode
# AAACCCAAGAGTCTTC_1      Batch-1        2365          1221    3.171247
# AAACCCAAGGACTTCT_1      Batch-1        2022          1135    2.670623
# AAACCCAGTCACCACG_1      Batch-1        4096          1645    1.489258
# AAACCCAGTCACTCTC_1      Batch-1        3429          1555    5.074366
# AAACCCAGTTCCTTGC_1      Batch-1        3664          1580    2.429039
# ...                         ...         ...           ...         ...
# TTTGGAGGTCTTTCAT-1_4    Batch-4        6870          2258    2.299854
# TTTGGAGGTTTGGAAA-1_4    Batch-4       22517          4935    3.428521
# TTTGGTTCAGTGGCTC-1_4    Batch-4        4698          2190    2.745849
# TTTGGTTTCTTTACAC-1_4    Batch-4        4805          1891    7.908429
# TTTGTTGGTCGTCATA-1_4    Batch-4       10713          3398    3.043032
#
#                       seurat_clusters  nCount_LMO  nFeature_LMO  \
# barcode
# AAACCCAAGAGTCTTC_1                  1        1219             4
# AAACCCAAGGACTTCT_1                  8        1440             4
# AAACCCAGTCACCACG_1                  0        1909             4
# AAACCCAGTCACTCTC_1                  1        1478             4
# AAACCCAGTTCCTTGC_1                 12        1700             4
# ...                               ...         ...           ...
# TTTGGAGGTCTTTCAT-1_4                0         532             8
# TTTGGAGGTTTGGAAA-1_4                4         599             8
# TTTGGTTCAGTGGCTC-1_4                3         802             8
# TTTGGTTTCTTTACAC-1_4                6         651             8
# TTTGTTGGTCGTCATA-1_4                4         578             8
#
#                                 LMO_maxID         LMO_secondID  LMO_margin  \
# barcode
# AAACCCAAGAGTCTTC_1       Sample4-ACCAATGC     Sample1-TGTGATGG    0.578025
# AAACCCAAGGACTTCT_1       Sample4-ACCAATGC     Sample1-TGTGATGG    0.604401
# AAACCCAGTCACCACG_1       Sample4-ACCAATGC     Sample1-TGTGATGG    0.898188
# AAACCCAGTCACTCTC_1       Sample1-TGTGATGG     Sample4-ACCAATGC    0.465037
# AAACCCAGTTCCTTGC_1       Sample1-TGTGATGG     Sample3-CTCTAGAC    0.828595
# ...                                   ...                  ...         ...
# TTTGGAGGTCTTTCAT-1_4   BC21-23.9-GAGAGACT   BC22-24.9-CGATTAGC    0.333547
# TTTGGAGGTTTGGAAA-1_4  BC24-25.93-TGTACCAG  BC23-25.93-ATCTACGG    0.485408
# TTTGGTTCAGTGGCTC-1_4  BC18-14.77-TTCCACGT   BC17-3.60-ACTCGAAG    1.105339
# TTTGGTTTCTTTACAC-1_4  BC24-25.93-TGTACCAG   BC22-24.9-CGATTAGC    0.742771
# TTTGTTGGTCGTCATA-1_4   BC17-3.60-ACTCGAAG  BC23-25.93-ATCTACGG    0.458629
#
#                       ... SCT_snn_res.0.15 SCT_snn_res.0.18 SCT_snn_res.0.19  \
# barcode               ...
# AAACCCAAGAGTCTTC_1    ...                0                0                0
# AAACCCAAGGACTTCT_1    ...                6                7                7
# AAACCCAGTCACCACG_1    ...                2                1                1
# AAACCCAGTCACTCTC_1    ...                0                0                0
# AAACCCAGTTCCTTGC_1    ...                9               10               10
# ...                   ...              ...              ...              ...
# TTTGGAGGTCTTTCAT-1_4  ...                2                1                1
# TTTGGAGGTTTGGAAA-1_4  ...                4                5                5
# TTTGGTTCAGTGGCTC-1_4  ...                3                3                3
# TTTGGTTTCTTTACAC-1_4  ...                5                6                6
# TTTGTTGGTCGTCATA-1_4  ...                4                5                5
#
#                       SCT_snn_res.0.17  SCT_snn_res.0.3 SCT_snn_res.0.4  \
# barcode
# AAACCCAAGAGTCTTC_1                   0                1               1
# AAACCCAAGGACTTCT_1                   7                8               8
# AAACCCAGTCACCACG_1                   1                0               0
# AAACCCAGTCACTCTC_1                   0                1               1
# AAACCCAGTTCCTTGC_1                  10               12              13
# ...                                ...              ...             ...
# TTTGGAGGTCTTTCAT-1_4                 1                0               0
# TTTGGAGGTTTGGAAA-1_4                 5                4               5
# TTTGGTTCAGTGGCTC-1_4                 3                3               2
# TTTGGTTTCTTTACAC-1_4                 6                6               6
# TTTGTTGGTCGTCATA-1_4                 5                4               5
#
#                      Prolif_Lineage_Fraction_of_SVZ               barcode  \
# barcode
# AAACCCAAGAGTCTTC_1                         0.058700    AAACCCAAGAGTCTTC_1
# AAACCCAAGGACTTCT_1                         0.058700    AAACCCAAGGACTTCT_1
# AAACCCAGTCACCACG_1                         0.058700    AAACCCAGTCACCACG_1
# AAACCCAGTCACTCTC_1                         0.208150    AAACCCAGTCACTCTC_1
# AAACCCAGTTCCTTGC_1                         0.208150    AAACCCAGTTCCTTGC_1
# ...                                             ...                   ...
# TTTGGAGGTCTTTCAT-1_4                       0.084746  TTTGGAGGTCTTTCAT-1_4
# TTTGGAGGTTTGGAAA-1_4                       0.142076  TTTGGAGGTTTGGAAA-1_4
# TTTGGTTCAGTGGCTC-1_4                       0.189448  TTTGGTTCAGTGGCTC-1_4
# TTTGGTTTCTTTACAC-1_4                       0.142076  TTTGGTTTCTTTACAC-1_4
# TTTGTTGGTCGTCATA-1_4                       0.327504  TTTGTTGGTCGTCATA-1_4
#
#                          UMAP_1     UMAP_2
# barcode
# AAACCCAAGAGTCTTC_1    -3.547333 -12.970000
# AAACCCAAGGACTTCT_1   -10.232237  -1.107690
# AAACCCAGTCACCACG_1    -1.192643   4.016450
# AAACCCAGTCACTCTC_1    -0.087583 -18.130805
# AAACCCAGTTCCTTGC_1     2.247815  -7.063813
# ...                         ...        ...
# TTTGGAGGTCTTTCAT-1_4   1.631252  -1.025304
# TTTGGAGGTTTGGAAA-1_4  -9.406291   5.631098
# TTTGGTTCAGTGGCTC-1_4   9.433035  -7.635666
# TTTGGTTTCTTTACAC-1_4 -13.037850  -4.041263
# TTTGTTGGTCGTCATA-1_4 -13.307740   6.321906
#
# [21458 rows x 34 columns]

# %%
ages_df = pd.DataFrame(neuron_age_data.obs["Age"])
ages_df
# Out:
#                         Age
# barcode
# AAACCCAAGAGTCTTC_1    29.00
# AAACCCAAGGACTTCT_1    29.00
# AAACCCAGTCACCACG_1    29.00
# AAACCCAGTCACTCTC_1     4.70
# AAACCCAGTTCCTTGC_1     4.70
# ...                     ...
# TTTGGAGGTCTTTCAT-1_4  23.90
# TTTGGAGGTTTGGAAA-1_4  25.93
# TTTGGTTCAGTGGCTC-1_4  14.77
# TTTGGTTTCTTTACAC-1_4  25.93
# TTTGTTGGTCGTCATA-1_4   3.60
#
# [21458 rows x 1 columns]

# %%
ages_df = ages_df.astype(int)
np.unique(ages_df)
# Out:
# array([ 3,  4,  5,  6,  8,  9, 10, 12, 14, 16, 18, 20, 21, 22, 23, 24, 25,
#        29])

# %%
ages_df
# Out:
#                       Age
# barcode
# AAACCCAAGAGTCTTC_1     29
# AAACCCAAGGACTTCT_1     29
# AAACCCAGTCACCACG_1     29
# AAACCCAGTCACTCTC_1      4
# AAACCCAGTTCCTTGC_1      4
# ...                   ...
# TTTGGAGGTCTTTCAT-1_4   23
# TTTGGAGGTTTGGAAA-1_4   25
# TTTGGTTCAGTGGCTC-1_4   14
# TTTGGTTTCTTTACAC-1_4   25
# TTTGTTGGTCGTCATA-1_4    3
#
# [21458 rows x 1 columns]

# %%
ages = list(ages_df["Age"])

# %%
age_groups = np.unique(ages)
age_groups
# Out:
# array([ 3,  4,  5,  6,  8,  9, 10, 12, 14, 16, 18, 20, 21, 22, 23, 24, 25,
#        29])

# %% [markdown]
# ## Generate Raw Counts

# %%
raw_count = pd.DataFrame.sparse.from_spmatrix(neuron_age_data.X.T, 
                                               index = neuron_age_data.var_names, 
                                               columns = neuron_age_data.obs_names).astype(int)

# %%
raw_count
# Out:
# barcode         AAACCCAAGAGTCTTC_1  AAACCCAAGGACTTCT_1  AAACCCAGTCACCACG_1  \
# Xkr4                             0                   0                   0
# Gm1992                           0                   0                   0
# Gm37381                          0                   0                   0
# Rp1                              0                   0                   0
# Sox17                            0                   0                   0
# ...                            ...                 ...                 ...
# AC168977.1                       0                   0                   0
# AC149090.1                       0                   1                   2
# CAAA01118383.1                   0                   0                   0
# Vmn2r122                         0                   0                   0
# CAAA01147332.1                   0                   0                   0
#
# barcode         AAACCCAGTCACTCTC_1  AAACCCAGTTCCTTGC_1  AAACCCATCACTGAAC_1  \
# Xkr4                             0                   0                   0
# Gm1992                           0                   0                   0
# Gm37381                          0                   0                   0
# Rp1                              0                   0                   0
# Sox17                            0                   0                   0
# ...                            ...                 ...                 ...
# AC168977.1                       0                   0                   0
# AC149090.1                       0                   1                   3
# CAAA01118383.1                   0                   0                   0
# Vmn2r122                         0                   0                   0
# CAAA01147332.1                   0                   0                   0
#
# barcode         AAACCCATCCTGCTAC_1  AAACCCATCGTTGTTT_1  AAACCCATCTTAGCAG_1  \
# Xkr4                             0                   0                   0
# Gm1992                           0                   0                   0
# Gm37381                          0                   0                   0
# Rp1                              0                   0                   0
# Sox17                            0                   0                   0
# ...                            ...                 ...                 ...
# AC168977.1                       0                   0                   0
# AC149090.1                       0                   1                   0
# CAAA01118383.1                   0                   0                   0
# Vmn2r122                         0                   0                   0
# CAAA01147332.1                   0                   0                   0
#
# barcode         AAACGAAAGTTACGTC_1  ...  TTTGGAGCAATTGCTG-1_4  \
# Xkr4                             0  ...                     0
# Gm1992                           0  ...                     0
# Gm37381                          0  ...                     0
# Rp1                              0  ...                     0
# Sox17                            0  ...                     0
# ...                            ...  ...                   ...
# AC168977.1                       0  ...                     0
# AC149090.1                       0  ...                     0
# CAAA01118383.1                   0  ...                     0
# Vmn2r122                         0  ...                     0
# CAAA01147332.1                   0  ...                     0
#
# barcode         TTTGGAGCAGCTACTA-1_4  TTTGGAGCATCAACCA-1_4  \
# Xkr4                               0                     0
# Gm1992                             0                     0
# Gm37381                            0                     0
# Rp1                                0                     0
# Sox17                              0                     0
# ...                              ...                   ...
# AC168977.1                         0                     0
# AC149090.1                         0                     1
# CAAA01118383.1                     0                     0
# Vmn2r122                           0                     0
# CAAA01147332.1                     0                     0
#
# barcode         TTTGGAGCATTGCAAC-1_4  TTTGGAGGTAGAGGAA-1_4  \
# Xkr4                               0                     0
# Gm1992                             0                     0
# Gm37381                            0                     0
# Rp1                                0                     0
# Sox17                              0                     0
# ...                              ...                   ...
# AC168977.1                         0                     0
# AC149090.1                         0                     0
# CAAA01118383.1                     0                     0
# Vmn2r122                           0                     0
# CAAA01147332.1                     0                     0
#
# barcode         TTTGGAGGTCTTTCAT-1_4  TTTGGAGGTTTGGAAA-1_4  \
# Xkr4                               0                     0
# Gm1992                             0                     0
# Gm37381                            0                     0
# Rp1                                0                     0
# Sox17                              0                     0
# ...                              ...                   ...
# AC168977.1                         0                     0
# AC149090.1                         1                     1
# CAAA01118383.1                     0                     1
# Vmn2r122                           0                     0
# CAAA01147332.1                     0                     0
#
# barcode         TTTGGTTCAGTGGCTC-1_4  TTTGGTTTCTTTACAC-1_4  \
# Xkr4                               0                     0
# Gm1992                             0                     0
# Gm37381                            0                     0
# Rp1                                0                     0
# Sox17                              0                     0
# ...                              ...                   ...
# AC168977.1                         0                     0
# AC149090.1                         2                     0
# CAAA01118383.1                     0                     0
# Vmn2r122                           0                     0
# CAAA01147332.1                     0                     0
#
# barcode         TTTGTTGGTCGTCATA-1_4
# Xkr4                               0
# Gm1992                             0
# Gm37381                            0
# Rp1                                0
# Sox17                              0
# ...                              ...
# AC168977.1                         0
# AC149090.1                         0
# CAAA01118383.1                     0
# Vmn2r122                           0
# CAAA01147332.1                     0
#
# [31053 rows x 21458 columns]

# %%
celltype_names[celltype_dict[1]]
# Out:
#    AAACCCAAGAGTCTTC_1 AAACCCAGTCACTCTC_1 AAACCCATCCTGCTAC_1  \
# V1        Oligodendro        Oligodendro        Oligodendro
#
#    AAACCCATCTTAGCAG_1 AAACGAACAGCAGTTT_1 AAACGCTGTCTACATG_1  \
# V1        Oligodendro        Oligodendro        Oligodendro
#
#    AAAGAACCATCATTGG_1 AAAGGATCATCGTGCG_1 AAAGGGCCATGTTACG_1  \
# V1        Oligodendro        Oligodendro        Oligodendro
#
#    AAAGGGCTCTGCCTCA_1  ... TTTCAGTAGACGACGT-1_4 TTTCATGTCGTGGACC-1_4  \
# V1        Oligodendro  ...          Oligodendro          Oligodendro
#
#    TTTCCTCCAGGATTCT-1_4 TTTCCTCGTACTTGTG-1_4 TTTCGATCAAAGGAGA-1_4  \
# V1          Oligodendro          Oligodendro          Oligodendro
#
#    TTTCGATCACTTCATT-1_4 TTTGACTCACAGTCCG-1_4 TTTGGAGAGCCGTTGC-1_4  \
# V1          Oligodendro          Oligodendro          Oligodendro
#
#    TTTGGAGGTAGAGGAA-1_4 TTTGGTTTCTTTACAC-1_4
# V1          Oligodendro          Oligodendro
#
# [1 rows x 5943 columns]

# %%
gene_names = np.array(raw_count.index)

# %% [markdown]
# ## Generate MetaCells

# %%
#def get_metaCells():
metaCells = {}
for celltype in tqdm(Counter(neuron_age_data.obs["Celltype.LowRes"])):
    cell_group = raw_count[celltype_dict[celltype]]
    current_ages = ages_df.T[celltype_dict[celltype]].T
    metaCells[celltype] = []
    for age in age_groups:
        current_group = current_ages[current_ages["Age"] == age]
        meta_cells = cell_group[current_group.index]
        meta_cells = np.sum(meta_cells, axis = 1)
        metaCells[celltype].append(meta_cells)
# Out:
# 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]

# %%
pd.DataFrame(metaCells["Oligodendro"])
# Out:
#     Xkr4  Gm1992  Gm37381  Rp1  Sox17  Gm37323  Mrpl15  Lypla1  Gm37988  \
# 0     31       0        0    0      0        0     276      55        0
# 1     26       0        0    0      0        0     216      47        1
# 2     20       0        0    0      0        0     162      43        0
# 3     13       0        0    0      0        0     132      27        0
# 4     19       0        0    0      0        0     110      23        2
# 5      7       0        0    0      0        0      54      13        0
# 6     30       0        0    0      1        0     213      46        0
# 7     18       0        0    0      1        0     148      30        1
# 8     12       0        0    0      0        0     172      52        0
# 9      6       1        0    0      1        0      75      29        0
# 10    11       0        0    0      0        0     138      42        0
# 11    16       0        0    0      0        0     165      38        0
# 12     3       0        0    0      0        0      80      26        0
# 13     7       0        0    0      0        0     122      26        2
# 14     2       0        0    0      0        0      49       3        0
# 15     8       0        0    0      0        0      61      18        0
# 16     5       0        0    0      0        0      65      26        0
# 17    16       0        0    0      1        0     146      35        0
#
#     Tcea1  ...  AC125149.1  AC125149.2  AC125149.4  AC234645.1  AC168977.2  \
# 0     453  ...           0           0           0           0           0
# 1     414  ...           0           0           0           0           0
# 2     304  ...           0           0           0           0           0
# 3     217  ...           0           0           0           0           0
# 4     177  ...           0           0           0           0           0
# 5     115  ...           0           0           0           0           0
# 6     310  ...           0           0           0           0           0
# 7     224  ...           0           0           0           0           0
# 8     308  ...           0           0           0           0           0
# 9     120  ...           0           0           0           0           0
# 10    257  ...           0           0           0           0           0
# 11    297  ...           0           0           0           0           0
# 12    146  ...           0           0           0           0           0
# 13    203  ...           0           0           0           0           0
# 14     66  ...           0           0           0           0           0
# 15    119  ...           0           0           0           0           0
# 16    145  ...           0           0           0           0           0
# 17    251  ...           0           0           0           0           0
#
#     AC168977.1  AC149090.1  CAAA01118383.1  Vmn2r122  CAAA01147332.1
# 0            0         137             103         0               4
# 1            0         179              86         0               3
# 2            0         139              62         0               1
# 3            0         137              62         0               3
# 4            0          44              45         0               1
# 5            0          45              21         0               0
# 6            0          78              83         0               2
# 7            0          74              49         0               4
# 8            0         104              58         0               1
# 9            0          75              23         0               0
# 10           0         115              40         0               3
# 11           0         252              63         0               1
# 12           0          56              25         0               2
# 13           0          71              37         0               2
# 14           0          13              12         0               0
# 15           0          77              34         0               2
# 16           0          76              16         0               3
# 17           0         164              56         0               2
#
# [18 rows x 31053 columns]

# %%
import Helper.get_norm_expression
norm_metaCells = {}
for i in metaCells:
    normalized_df = Helper.get_norm_expression.normalization(metaCells[i])
    norm_metaCells[i] = normalized_df

# %%
norm_metaCells["Oligodendro"]
# Out:
#          Xkr4    Gm1992  Gm37381  Rp1     Sox17  Gm37323      Mrpl15  \
# 0   13.070020  0.000000      0.0  0.0  0.000000      0.0  116.365342
# 1   14.650693  0.000000      0.0  0.0  0.000000      0.0  121.713450
# 2   15.624423  0.000000      0.0  0.0  0.000000      0.0  126.557824
# 3   13.457514  0.000000      0.0  0.0  0.000000      0.0  136.645525
# 4   22.236189  0.000000      0.0  0.0  0.000000      0.0  128.735833
# 5   14.013986  0.000000      0.0  0.0  0.000000      0.0  108.107893
# 6   19.278150  0.000000      0.0  0.0  0.642605      0.0  136.874868
# 7   17.408176  0.000000      0.0  0.0  0.967121      0.0  143.133891
# 8    9.564097  0.000000      0.0  0.0  0.000000      0.0  137.085388
# 9   10.534511  1.755752      0.0  0.0  1.755752      0.0  131.681383
# 10   9.542685  0.000000      0.0  0.0  0.000000      0.0  119.717324
# 11  12.688098  0.000000      0.0  0.0  0.000000      0.0  130.846008
# 12   5.064539  0.000000      0.0  0.0  0.000000      0.0  135.054381
# 13   7.377027  0.000000      0.0  0.0  0.000000      0.0  128.571049
# 14   6.942212  0.000000      0.0  0.0  0.000000      0.0  170.084189
# 15  13.107858  0.000000      0.0  0.0  0.000000      0.0   99.947421
# 16   8.176888  0.000000      0.0  0.0  0.000000      0.0  106.299541
# 17  15.274788  0.000000      0.0  0.0  0.954674      0.0  139.382441
#
#        Lypla1   Gm37988       Tcea1  ...  AC125149.1  AC125149.2  AC125149.4  \
# 0   23.188746  0.000000  190.990942  ...         0.0         0.0         0.0
# 1   26.483945  0.563488  233.284113  ...         0.0         0.0         0.0
# 2   33.592509  0.000000  237.491226  ...         0.0         0.0         0.0
# 3   27.950221  0.000000  224.636961  ...         0.0         0.0         0.0
# 4   26.917492  2.340652  207.147659  ...         0.0         0.0         0.0
# 5   26.025974  0.000000  230.229773  ...         0.0         0.0         0.0
# 6   29.559831  0.000000  199.207554  ...         0.0         0.0         0.0
# 7   29.013627  0.967121  216.635078  ...         0.0         0.0         0.0
# 8   41.444420  0.000000  245.478485  ...         0.0         0.0         0.0
# 9   50.916801  0.000000  210.690213  ...         0.0         0.0         0.0
# 10  36.435707  0.000000  222.951829  ...         0.0         0.0         0.0
# 11  30.134232  0.000000  235.522814  ...         0.0         0.0         0.0
# 12  43.892674  0.000000  246.474246  ...         0.0         0.0         0.0
# 13  27.400387  2.107722  213.933794  ...         0.0         0.0         0.0
# 14  10.413318  0.000000  229.092989  ...         0.0         0.0         0.0
# 15  29.492682  0.000000  194.979395  ...         0.0         0.0         0.0
# 16  42.519816  0.000000  237.129745  ...         0.0         0.0         0.0
# 17  33.413599  0.000000  239.623238  ...         0.0         0.0         0.0
#
#     AC234645.1  AC168977.2  AC168977.1  AC149090.1  CAAA01118383.1  Vmn2r122  \
# 0          0.0         0.0         0.0   57.761057       43.426196       0.0
# 1          0.0         0.0         0.0  100.864387       48.459985       0.0
# 2          0.0         0.0         0.0  108.589738       48.435711       0.0
# 3          0.0         0.0         0.0  141.821491       64.181989       0.0
# 4          0.0         0.0         0.0   51.494333       52.664659       0.0
# 5          0.0         0.0         0.0   90.089911       42.041958       0.0
# 6          0.0         0.0         0.0   50.123191       53.336216       0.0
# 7          0.0         0.0         0.0   71.566946       47.388923       0.0
# 8          0.0         0.0         0.0   82.888839       46.226468       0.0
# 9          0.0         0.0         0.0  131.681383       40.382291       0.0
# 10         0.0         0.0         0.0   99.764437       34.700674       0.0
# 11         0.0         0.0         0.0  199.837539       49.959385       0.0
# 12         0.0         0.0         0.0   94.538067       42.204494       0.0
# 13         0.0         0.0         0.0   74.824135       38.992859       0.0
# 14         0.0         0.0         0.0   45.124377       41.653271       0.0
# 15         0.0         0.0         0.0  126.163138       55.708398       0.0
# 16         0.0         0.0         0.0  124.288694       26.166041       0.0
# 17         0.0         0.0         0.0  156.566578       53.461758       0.0
#
#     CAAA01147332.1
# 0         1.686454
# 1         1.690465
# 2         0.781221
# 3         3.105580
# 4         1.170326
# 5         0.000000
# 6         1.285210
# 7         3.868484
# 8         0.797008
# 9         0.000000
# 10        2.602551
# 11        0.793006
# 12        3.376360
# 13        2.107722
# 14        0.000000
# 15        3.276965
# 16        4.906133
# 17        1.909349
#
# [18 rows x 31053 columns]

# %% [markdown]
# ## Compute Top-correlated Gene Lists

# %%
correlated_genes = {}
correlations = {}
for celltype in norm_metaCells:
    current_cell = norm_metaCells[celltype]
    curr = []
    for gene in current_cell:
        curr.append(abs(stats.pearsonr(current_cell[gene], age_groups)[0]))
    curr = np.nan_to_num(np.array(curr))
    order = np.argsort(curr)
    correlations[celltype] = curr[order][::-1]
    correlated_genes[celltype] = list(gene_names[order][::-1])
#     file = pd.DataFrame(curr[order][::-1], index = np.array(gene_names[order][::-1]).flatten())
#     file.to_csv("Correlation_info_matrix/" + str(celltype) + " subtype_correlations.csv")

# %%
# correlated_genes[1][:10]
correlated_genes["Oligodendro"][:10]
# Out:
# ['Dpyd',
#  'Ogdhl',
#  'Abca8a',
#  'Gstm6',
#  'Ccdc136',
#  'R3hdm1',
#  'Cdk14',
#  'Tmem150c',
#  'Pmp22',
#  'Acot11']

# %%
# test = norm_metaCells[1].T
test = norm_metaCells["Oligodendro"].T
test.columns = age_groups
# top100 = correlated_genes[1][:100]
top100 = correlated_genes["Oligodendro"][:100]

# %%
import seaborn as sns
figure, axes = plt.subplots(3, 3, figsize = (16,16))
axes = axes.ravel()
genes = top100[:9]
for i in tqdm(range(len(list(genes)))):
    data = []
    for age in age_groups:
        data.append(list(test[age].loc[[genes[i]]])[0])
    axes[i].scatter(age_groups, data)
    z = np.polyfit(age_groups, data, 1)
    p = np.poly1d(z)
    axes[i].plot(age_groups, p(age_groups))
    axes[i].set_title(genes[i], fontsize=16)
figure.supylabel("Normalized Meta-cell Counts", fontsize=20)
figure.supxlabel("Actual Age", fontsize=20)
figure.tight_layout()
plt.show()
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 108.78it/s]

# %%
# df = pd.DataFrame(metaCells[1]).T
df = pd.DataFrame(metaCells["Oligodendro"]).T
df.columns = age_groups

# %%
from sklearn.metrics import r2_score
figure, axes = plt.subplots(3, 3, figsize = (16,16))
axes = axes.ravel()
genes = top100[:9]
for i in tqdm(range(len(list(genes)))):
    data = []
    for age in age_groups:
        data.append(list(df[age].loc[[genes[i]]])[0])
    axes[i].scatter(age_groups, data)
    z = np.polyfit(age_groups, data, 1)
    p = np.poly1d(z)
    axes[i].plot(age_groups, p(age_groups))
    axes[i].set_title(genes[i], fontsize=16)
figure.supylabel("Raw Meta-cell Counts", fontsize=20)
figure.supxlabel("Actual Age", fontsize=20)
figure.tight_layout()
plt.show()
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 121.69it/s]

# %% [markdown]
# ## Use Top 100 abs Correlated Genes to Compute Frequencies for Each Gene at Each Specific Age Group

# %% [markdown]
# ### fraction of gene count itself for specific age
# count_gene for that age/ total_count of genes of the whole matrix

# %% [markdown]
# ### celltype 6 does not have age group 23

# %%
train_ages = {}
pred_freq_matrices = {}
for celltype in metaCells:
    df = pd.DataFrame(metaCells[celltype])[correlated_genes[celltype][:100]]
    df.index = age_groups
    frequency_matrix = df.div(np.sum(df, axis = 1), axis = 0)
    frequency_matrix = frequency_matrix.fillna(0)
    pred_freqs = np.zeros((frequency_matrix.shape))
    pred_freqs = pd.DataFrame(pred_freqs, columns=frequency_matrix.columns)
    train_age = np.array(frequency_matrix.index).reshape(-1,1)
    for gene in frequency_matrix:
        reg = LinearRegression(n_jobs=1).fit(train_age, np.array(frequency_matrix[gene]))
        predictions = reg.predict(train_age)
        pred_freqs[gene] = predictions
    pred_freqs[pred_freqs < 0] = 1e-6
    pred_freqs = pred_freqs.T
    pred_freqs.columns = frequency_matrix.index
    #pred_freqs.to_csv("./Frequency_matrix/" + str(celltype) + "_subtype_fraction.csv")
    pred_freq_matrices[celltype] = pred_freqs
    train_ages[celltype] = train_age

# %%
# pred_freq_matrices[6]
pred_freq_matrices["Oligodendro"]
# Out:
#                3         4         5         6         8         9         10  \
# Dpyd     0.000664  0.000726  0.000788  0.000850  0.000973  0.001035  0.001097
# Ogdhl    0.000287  0.000370  0.000453  0.000536  0.000701  0.000784  0.000867
# Abca8a   0.007595  0.007774  0.007952  0.008131  0.008488  0.008666  0.008845
# Gstm6    0.001698  0.001761  0.001824  0.001886  0.002012  0.002074  0.002137
# Ccdc136  0.000880  0.000935  0.000990  0.001045  0.001155  0.001210  0.001265
# ...           ...       ...       ...       ...       ...       ...       ...
# Lmo7     0.000176  0.000168  0.000160  0.000153  0.000138  0.000130  0.000122
# Fmo5     0.000344  0.000359  0.000374  0.000389  0.000419  0.000435  0.000450
# Gm4221   0.001933  0.001859  0.001785  0.001711  0.001564  0.001490  0.001416
# Sag      0.000056  0.000066  0.000076  0.000087  0.000108  0.000118  0.000128
# Pcdhb18  0.000376  0.000400  0.000423  0.000447  0.000495  0.000519  0.000542
#
#                12        14        16        18        20        21        22  \
# Dpyd     0.001220  0.001344  0.001467  0.001590  0.001714  0.001776  0.001837
# Ogdhl    0.001032  0.001198  0.001364  0.001529  0.001695  0.001778  0.001861
# Abca8a   0.009202  0.009559  0.009916  0.010273  0.010630  0.010809  0.010988
# Gstm6    0.002262  0.002388  0.002513  0.002639  0.002764  0.002827  0.002890
# Ccdc136  0.001375  0.001485  0.001595  0.001705  0.001815  0.001870  0.001925
# ...           ...       ...       ...       ...       ...       ...       ...
# Lmo7     0.000107  0.000092  0.000077  0.000062  0.000046  0.000039  0.000031
# Fmo5     0.000480  0.000510  0.000541  0.000571  0.000601  0.000616  0.000632
# Gm4221   0.001269  0.001121  0.000973  0.000826  0.000678  0.000604  0.000531
# Sag      0.000149  0.000170  0.000191  0.000211  0.000232  0.000243  0.000253
# Pcdhb18  0.000590  0.000638  0.000685  0.000733  0.000781  0.000804  0.000828
#
#                23        24        25        29
# Dpyd     0.001899  0.001961  0.002023  0.002270
# Ogdhl    0.001944  0.002026  0.002109  0.002441
# Abca8a   0.011166  0.011345  0.011523  0.012237
# Gstm6    0.002952  0.003015  0.003078  0.003328
# Ccdc136  0.001980  0.002035  0.002090  0.002310
# ...           ...       ...       ...       ...
# Lmo7     0.000024  0.000016  0.000008  0.000001
# Fmo5     0.000647  0.000662  0.000677  0.000738
# Gm4221   0.000457  0.000383  0.000309  0.000014
# Sag      0.000263  0.000274  0.000284  0.000326
# Pcdhb18  0.000852  0.000876  0.000900  0.000995
#
# [100 rows x 18 columns]

# %% [markdown]
# ## linear model for each gene among all the age groups

# %%
# pred_freqs = np.zeros((frequency_matrix.shape))
# pred_freqs = pd.DataFrame(pred_freqs, columns=frequency_matrix.columns)
# train_ages = np.array(frequency_matrix.index).reshape(-1,1)
# for gene in frequency_matrix:
#     reg = LinearRegression(n_jobs=1).fit(train_ages, np.array(frequency_matrix[gene]))
#     predictions = reg.predict(train_ages)
#     pred_freqs[gene] = predictions

# %%
# pred_freqs.index = age_groups

# %% [markdown]
# ## Trying Possion Probability
# r: Expected frequency from the linear model
# k: counts of this specific gene
# t: sum of the counts across all genes for that cell

# %%
# r: Expected frequency from the linear model
# k: counts of this specific gene
# t: sum of the counts across all genes for that cell
## only iterate the top 100 genes

# %% [markdown]
# ## Run Poisson

# %%
from scipy.stats import poisson
import math
from matplotlib.pyplot import figure
from sklearn.metrics import r2_score

# %%
# pd.DataFrame(metaCells[6])[correlated_genes[6][:100]]
pd.DataFrame(metaCells["Oligodendro"])[correlated_genes["Oligodendro"][:100]]
# Out:
#     Dpyd  Ogdhl  Abca8a  Gstm6  Ccdc136  R3hdm1  Cdk14  Tmem150c  Pmp22  \
# 0     19     16     178     45       27     624     38         3   1326
# 1     12      8     222     40       27     500     32         3   1286
# 2     13      8     122     40       18     327     24         5   1058
# 3     23     17     130     27       29     221     20         9    787
# 4     15      7     142     24        9     225     15         9    612
# 5      8      8      85     21       13     121      7         5    384
# 6     34     17     298     57       30     391     26        13   1141
# 7     20     25     169     42       24     259     13         8    783
# 8     26     21     233     69       38     258     17        14   1023
# 9     16     12     124     33       18     129      5        10    580
# 10    33     39     232     61       28     242      6        18   1047
# 11    59     49     223     63       56     266     11        11   1159
# 12    23      8     123     33       17     131      4         6    537
# 13    30     35     208     56       29     202     14        14    742
# 14    10      8      56     17       12      69      3         8    306
# 15    23     20     133     42       21     124      5        16    673
# 16    16     27     149     31       23     118      5        16    675
# 17    52     73     217     50       60     163      5        23   1133
#
#     Acot11  ...  Eif4e  Gm49375  2900011O08Rik  B3gnt2  Pes1  Lmo7  Fmo5  \
# 0        7  ...    303       47             10      18    81     5    14
# 1        6  ...    263       41              8      12    64     5    18
# 2        3  ...    170       32              3       6    40     6    11
# 3        3  ...    133       34              3       8    45     2     7
# 4        3  ...    109       28              1       6    22     1     4
# 5        1  ...     76       20              1       1    13     2     3
# 6        5  ...    230       72              3      10    50     1     7
# 7        1  ...    153       31              1       2    41     2     9
# 8        4  ...    180       53              2       3    55     2     7
# 9        3  ...     94       41              0       3    25     0     4
# 10       8  ...    168       47              0       3    46     3    13
# 11       5  ...    191       51              2       4    58     1    13
# 12       4  ...     90       37              1       3    22     1     6
# 13       5  ...    155       42              1       2    44     0    10
# 14       2  ...     55       23              0       1    13     0     4
# 15       5  ...    130       42              1       0    31     0    13
# 16       4  ...    104       27              0       1    36     0     9
# 17       8  ...    169       56              1       2    50     0    14
#
#     Gm4221  Sag  Pcdhb18
# 0      133    3       13
# 1       66    2        6
# 2       26    3       10
# 3       36    2        7
# 4       22    0        4
# 5        9    1        6
# 6       23    2       25
# 7       11    2        6
# 8       17    9       14
# 9        5    2        4
# 10       7    0       20
# 11      25    4       19
# 12       3    2       11
# 13      11    3       21
# 14       2    2        7
# 15      11    4        8
# 16       8    5        8
# 17       9    7       15
#
# [18 rows x 100 columns]

# %%
from collections import defaultdict
def get_cells_byAge(cell_group):
    cell_group_ages = ages_df.T[cell_group.index]
    cell_group_age_dict = defaultdict(list)
    for cell in cell_group_ages:
        cell_group_age_dict[cell_group_ages[cell].values[0]].append(cell)
    return cell_group_age_dict

# %%
def get_singleCell_sums(cells):
    cell_sums = np.sum(cells, axis = 0)
    return(cell_sums)

# %%
from numpy import inf
def run_poisson(celltype, pred_freqs, raw_cells, train_ages):
    outcome = defaultdict(list)
    freq_probs = defaultdict(list)
    for age in pred_freqs:
        cell_group_byAge = get_cells_byAge(raw_cells)
        cell_group = raw_cells.T[cell_group_byAge[age]]
        cell_sums = get_singleCell_sums(cell_group)
        for cell in cell_group:
            _lambda = pred_freqs * cell_sums[cell] # frequency of that gene expression * counts of all genes in that cell
            prob = poisson.pmf(np.array(cell_group[cell]).reshape(-1,1), _lambda)
            max_value = np.log(prob)
            max_value[max_value == -inf] = 0
            temp = np.sum(max_value, axis = 0).reshape(1,-1)
            #print("sum of loglikelihood: ")
            #display(pd.DataFrame(temp, columns = age_groups))
            #print(np.argmax(np.sum(np.log(prob), axis = 0)))
            max_value = train_ages[np.argmax(np.sum(max_value, axis = 0))]
            freq_probs[age].append(np.sum(np.log(prob), axis = 0))
            outcome[age].append(max_value[0])
    pred_results[celltype] = outcome
    likelihood[celltype] = freq_probs
        #print("predicted_result: ", max_value[0], " true_value: ", cell)

# %%
pred_results = {}
likelihood = {}
for celltype in pred_freq_matrices:
    print(celltype)
    run_poisson(celltype, pred_freq_matrices[celltype], pd.DataFrame(raw_count[celltype_dict[celltype]]).T[correlated_genes[celltype][:100]], train_ages[celltype])
# Out:
# Oligodendro
# Endothelial
# Microglia
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log
# Macrophage
# Astrocyte_qNSC
# aNSC_NPC
# Mural
# Ependymal
# Neuroblast
# OPC
# Neuron

# %%
def plot_violin(x, y, name):
    figure(figsize=(10, 4), dpi=80)
    r_squared = r2_score(x, y)
    ax = sns.violinplot(x, y)
    plt.ylabel("Predicted Age")
    plt.xlabel("True Age")
    plt.title(name)
    plt.legend(title = f"R-squared = {r_squared:.2f}", loc = "upper left")
    # adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5))
    plt.show()

# %%
names = []

# %%
for cell in pred_results:
    outcome = pred_results[cell]
    predicted_age = [int(inner) for outer in list(outcome.values()) for inner in outer]
    actual_age = []
    for key in list(outcome.keys()):
        actual_age.extend(len(outcome[key]) * [key])
#     name = np.unique(celltype_names[celltype_dict[cell]])[0]
    name = cell
    names.append(name)
    plot_violin(actual_age, predicted_age, name)
# Out:
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
correlated = pd.DataFrame.from_dict(correlated_genes)
correlated.columns = names

# %%
correlated = correlated[:100]
correlated
# Out:
#    Oligodendro    Endothelial Microglia Macrophage Astrocyte_qNSC  aNSC_NPC  \
# 0         Dpyd         Zswim7     Crlf2       Nav1            C4b     Lin7a
# 1        Ogdhl          Wdfy2      Sdf4     Zfp160       Slc22a18   Zc3hav1
# 2       Abca8a  2810474O19Rik  AW112010      Eva1b        Tspan13     Cebpa
# 3        Gstm6           Ppih     Plcl2     Rnf150          Ltbp4   Cyp20a1
# 4      Ccdc136           Plaa   Camk2n1       Gamt           Cnr1     Ednrb
# ..         ...            ...       ...        ...            ...       ...
# 95        Lmo7          Asxl3    Rprd1b       Nfya         Setbp1     Ifi27
# 96        Fmo5           Il16       Ly9      Chmp6       Ccdc102a  Tnfrsf17
# 97      Gm4221          Trem2     Ddx3y      Asb10         Pcyt1b     Pfdn6
# 98         Sag       Ifi27l2a     Elmo1        Ak3           Gbp2     Rwdd1
# 99     Pcdhb18           Irf7     Rbm26      Rsrp1          Ntrk3    Adora3
#
#        Mural      Ependymal Neuroblast            OPC   Neuron
# 0     Rilpl1  1810062G17Rik      Ccsap        Gm42372  Tsc22d1
# 1       Fmc1           Smg7      Coprs         Zfp292    Arl5a
# 2       Wars  C230035I16Rik       Fggy          Itgav    Aldh2
# 3    Gpatch1           Urah       Fis1           Jcad     Zhx1
# 4    Sipa1l1         Cep126     Dmrta2          Brwd3     Mesd
# ..       ...            ...        ...            ...      ...
# 95       Nvl        Rarres2        Sf1           Ahi1     Phax
# 96      Top1            Omg     Camk1d          Gpld1    Tor1a
# 97  Phospho2        Arfgef3      Hspa9      D17Wsu92e    Cpsf6
# 98   Dpy19l3         Elmod3     Gas2l3           Skp2    Ascc3
# 99      Gon7        Osbpl1a       Imp3  4930513D17Rik    Gsto1
#
# [100 rows x 11 columns]

# %%
correlated.to_csv("metacells/correlated_genes_by_celltype.csv")

# %%
figure, axes = plt.subplots(6, 3, figsize = (20,24))
axes = axes.ravel()
cells = list(pred_freqs.columns)
for i in range(len(cells)):
    axes[i].scatter(list(age_groups), freq_probs[i])
    axes[i].set_title("age " + str(cells[i]))
    axes[i].invert_yaxis()
figure.supylabel("Sum of logs")
figure.supxlabel("Age model")
plt.show()
figure.savefig('metatcell_loglikelihood.png')

# %%
test["true"]
# Out:
# 0      3.0
# 1      4.0
# 2      5.0
# 3      6.0
# 4      8.0
# 5      9.0
# 6     10.0
# 7     12.0
# 8     14.0
# 9     16.0
# 10    18.0
# 11    20.0
# 12    21.0
# 13    22.0
# 14    23.0
# 15    24.0
# 16    25.0
# 17    29.0
# Name: true, dtype: float64

# %%
from matplotlib.pyplot import figure
from adjustText import adjust_text
figure(figsize=(6, 4), dpi=80)
x,y = test["true"], test["predicted"]
plt.scatter(test["true"], np.array(test["predicted"]))
labels = zip(x,y)
texts = []
for x, y, s in zip(test["true"], test["predicted"], labels):
    texts.append(plt.text(x, y, s, fontsize=8))
plt.ylabel("Predicted Age")
plt.xlim(2,30)
plt.ylim(2,30)
plt.xlabel("True Age")
adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5))
plt.show()

# %%
# from scipy.stats import nbinom
# # number of success n: 
# # probability of single success: frequency of that gene expression
# from numpy import inf
# outcome = []
# freq_probs = []
# for cell in pred_freqs:
#     cell_sum = cell_sums[cell]
#     n = pred_freqs * cell_sum # frequency of that gene expression * counts of all genes in that cell
#     prob = poisson.pmf(np.array(df.T[cell]).reshape(-1,1), _lambda)
#     max_value = np.log(prob)
#     max_value[max_value == -inf] = 0
#     print(np.sum(max_value, axis = 0))
# #    print(np.argmax(np.sum(np.log(prob), axis = 0)))
#     max_value = train_ages[np.argmax(np.sum(max_value, axis = 0))]
#     freq_probs.append(np.sum(np.log(prob), axis = 1))
#     outcome.append(max_value[0])
#     print(max_value[0])

# %%
test = pd.DataFrame(zip(outcome, list(df.index)), columns=["predicted", "true"])

# %%
test
# Out:
#     predicted  true
# 0         6.0   3.0
# 1         6.0   4.0
# 2         5.0   5.0
# 3         8.0   6.0
# 4         8.0   8.0
# 5        14.0   9.0
# 6         9.0  10.0
# 7        10.0  12.0
# 8        12.0  14.0
# 9        16.0  16.0
# 10       20.0  18.0
# 11       16.0  20.0
# 12       20.0  21.0
# 13       18.0  22.0
# 14       25.0  23.0
# 15       23.0  24.0
# 16       29.0  25.0
# 17       25.0  29.0

# %%
test[test["predicted"] == test["true"]].shape[0] / test.shape[0]
# Out:
# 0.16666666666666666

# %% [markdown]
# ## next step: sum the likelihood for each age for a single cell

# %%
oligodendro = raw_count[celltype_dict[1]].T[top100]

# %%
oligodendro
# Out:
#                       Dpyd  Ogdhl  Abca8a  Gstm6  Ccdc136  R3hdm1  Cdk14  \
# AAACCCAAGAGTCTTC_1       0      0       1      0        0       1      0
# AAACCCAGTCACTCTC_1       0      0       0      0        0       0      0
# AAACCCATCCTGCTAC_1       0      0       0      1        0       1      0
# AAACCCATCTTAGCAG_1       0      0       0      0        0       0      0
# AAACGAACAGCAGTTT_1       1      0       0      0        0       0      0
# ...                    ...    ...     ...    ...      ...     ...    ...
# TTTCGATCACTTCATT-1_4     0      0       0      2        0       0      0
# TTTGACTCACAGTCCG-1_4     0      0       0      0        0       2      0
# TTTGGAGAGCCGTTGC-1_4     0      0       0      0        0       0      0
# TTTGGAGGTAGAGGAA-1_4     0      1       1      0        0       1      0
# TTTGGTTTCTTTACAC-1_4     0      0       2      0        0       1      0
#
#                       Tmem150c  Pmp22  Acot11  ...  Eif4e  Gm49375  \
# AAACCCAAGAGTCTTC_1           0      1       0  ...      0        0
# AAACCCAGTCACTCTC_1           0      0       0  ...      0        0
# AAACCCATCCTGCTAC_1           0      2       0  ...      0        0
# AAACCCATCTTAGCAG_1           0      1       0  ...      2        0
# AAACGAACAGCAGTTT_1           0      2       0  ...      0        0
# ...                        ...    ...     ...  ...    ...      ...
# TTTCGATCACTTCATT-1_4         0      7       0  ...      0        0
# TTTGACTCACAGTCCG-1_4         0      1       0  ...      1        0
# TTTGGAGAGCCGTTGC-1_4         0     10       0  ...      0        0
# TTTGGAGGTAGAGGAA-1_4         0      6       0  ...      1        0
# TTTGGTTTCTTTACAC-1_4         0      3       0  ...      0        0
#
#                       2900011O08Rik  B3gnt2  Pes1  Lmo7  Fmo5  Gm4221  Sag  \
# AAACCCAAGAGTCTTC_1                0       0     0     0     0       0    0
# AAACCCAGTCACTCTC_1                0       0     0     0     0       0    0
# AAACCCATCCTGCTAC_1                0       0     0     0     0       0    0
# AAACCCATCTTAGCAG_1                0       0     0     0     0       0    0
# AAACGAACAGCAGTTT_1                0       0     0     0     0       0    0
# ...                             ...     ...   ...   ...   ...     ...  ...
# TTTCGATCACTTCATT-1_4              0       0     0     0     0       0    0
# TTTGACTCACAGTCCG-1_4              0       0     1     0     0       0    0
# TTTGGAGAGCCGTTGC-1_4              0       0     0     0     0       0    0
# TTTGGAGGTAGAGGAA-1_4              0       0     0     0     0       0    0
# TTTGGTTTCTTTACAC-1_4              0       0     0     0     0       0    0
#
#                       Pcdhb18
# AAACCCAAGAGTCTTC_1          0
# AAACCCAGTCACTCTC_1          0
# AAACCCATCCTGCTAC_1          0
# AAACCCATCTTAGCAG_1          0
# AAACGAACAGCAGTTT_1          0
# ...                       ...
# TTTCGATCACTTCATT-1_4        0
# TTTGACTCACAGTCCG-1_4        0
# TTTGGAGAGCCGTTGC-1_4        0
# TTTGGAGGTAGAGGAA-1_4        1
# TTTGGTTTCTTTACAC-1_4        0
#
# [5943 rows x 100 columns]

# %%
oli_cell_sums = np.sum(oligodendro, axis = 1)
oli_cell_sums = oli_cell_sums.T
oli_cell_sums
# Out:
# AAACCCAAGAGTCTTC_1      21
# AAACCCAGTCACTCTC_1      33
# AAACCCATCCTGCTAC_1      43
# AAACCCATCTTAGCAG_1      58
# AAACGAACAGCAGTTT_1      36
#                         ..
# TTTCGATCACTTCATT-1_4    95
# TTTGACTCACAGTCCG-1_4    35
# TTTGGAGAGCCGTTGC-1_4    74
# TTTGGAGGTAGAGGAA-1_4    48
# TTTGGTTTCTTTACAC-1_4    62
# Length: 5943, dtype: int64

# %%
from collections import defaultdict
oligodendro_ages = ages_df.T[oligodendro.index]
oli_age_dict = defaultdict(list)
for cell in oligodendro_ages:
    oli_age_dict[oligodendro_ages[cell].values[0]].append(cell)
oli_age_dict
# Out:
# defaultdict(list,
#             {29.0: ['AAACCCAAGAGTCTTC_1',
#               'AAAGGATCATCGTGCG_1',
#               'AAAGTCCAGTTGGAAT_1',
#               'AAAGTCCTCCTCTAAT_1',
#               'AACAACCCAACCACAT_1',
#               'AACAACCTCTAGTACG_1',
#               'AACCACACAAACTGCT_1',
#               'AACCATGTCGAGATGG_1',
#               'AACCTGAAGTAGTCTC_1',
#               'AACCTGACATTCTGTT_1',
#               'AACGAAATCTAAGCGT_1',
#               'AAGATAGCAGAACGCA_1',
#               'AAGATAGTCTCTGCTG_1',
#               'AAGCGAGAGCACAAAT_1',
#               'AAGCGTTTCGCCAGAC_1',
#               'AAGCGTTTCGGATACT_1',
#               'AAGGAATTCACCCTTG_1',
#               'AAGGTAAGTCAAGTTC_1',
#               'AAGTCGTGTCTTTCAT_1',
#               'AAGTCGTGTTTGACAC_1',
#               'AAGTTCGCATGGAAGC_1',
#               'AAGTTCGGTGCACGCT_1',
#               'AATCACGTCATTTGCT_1',
#               'AATCACGTCTAACACG_1',
#               'AATCGACAGATACAGT_1',
#               'AATGCCAAGACTGAGC_1',
#               'AATGCCACACGCTATA_1',
#               'AATGGAAAGAAAGTCT_1',
#               'AATGGAATCCTTCTAA_1',
#               'AATTTCCGTGTTCAGT_1',
#               'ACACCAAGTTGAGAGC_1',
#               'ACAGAAAGTGTAACGG_1',
#               'ACATCGACATCTGGGC_1',
#               'ACCCAAAGTATACCTG_1',
#               'ACCCTCACACGTCGGT_1',
#               'ACCCTCATCCGCTTAC_1',
#               'ACCTACCTCATAAGGA_1',
#               'ACCTGAAGTCTTTATC_1',
#               'ACGATCAGTTGTGGAG_1',
#               'ACGCACGAGTGACCTT_1',
#               'ACGCACGGTATCGCGC_1',
#               'ACGGGTCGTTGGATCT_1',
#               'ACGGTCGGTTGAGGAC_1',
#               'ACGGTCGTCGTGGCGT_1',
#               'ACTACGAAGACGCCCT_1',
#               'ACTACGAGTGTGGTCC_1',
#               'ACTATCTAGCTAATCC_1',
#               'ACTCCCAAGTCGAAAT_1',
#               'ACTCTCGAGACTGTTC_1',
#               'ACTCTCGTCCTCTAAT_1',
#               'ACTGCAACAGGCAATG_1',
#               'ACTGCAAGTTCCTACC_1',
#               'ACTGTCCGTAATGCTC_1',
#               'ACTGTGAGTCACTGAT_1',
#               'ACTTAGGAGTCTTCGA_1',
#               'ACTTATCAGCACGTCC_1',
#               'ACTTATCGTGACAGGT_1',
#               'ACTTCCGAGTTGTAAG_1',
#               'AGAACCTGTGTCGATT_1',
#               'AGAAGCGGTCTAACGT_1',
#               'AGAAGCGGTGCTTCAA_1',
#               'AGAAGCGTCAACCGAT_1',
#               'AGAAGCGTCCTTCTGG_1',
#               'AGAAGTAAGCCTGAAG_1',
#               'AGACAGGAGCTAATGA_1',
#               'AGACAGGCAATATCCG_1',
#               'AGACAGGTCACAAGGG_1',
#               'AGACCCGGTCCGAAGA_1',
#               'AGACCCGTCACTTCTA_1',
#               'AGAGAATGTACGTGAG_1',
#               'AGAGAGCTCATGCCAA_1',
#               'AGAGCAGAGGTGGGTT_1',
#               'AGCGCCAGTGTGACCC_1',
#               'AGCGCTGCAGCCATTA_1',
#               'AGCGCTGCATGCCGGT_1',
#               'AGCTACAAGCAAACAT_1',
#               'AGCTTCCTCGCAGTGC_1',
#               'AGGACTTGTGTTCAGT_1',
#               'AGGAGGTGTTCCGTTC_1',
#               'AGGATCTGTGTACATC_1',
#               'AGGGAGTAGCAAATGT_1',
#               'AGGGTCCAGTTACGTC_1',
#               'AGGGTCCCAGATCACT_1',
#               'AGGGTCCTCCGTCACT_1',
#               'AGGGTGACACCACATA_1',
#               'AGGTCATTCGTAGAGG_1',
#               'AGTGCCGTCCGTGGTG_1',
#               'AGTGTTGCACGTTGGC_1',
#               'ATACCGACAGCTACTA_1',
#               'ATACCGATCCTAGCCT_1',
#               'ATACCGATCTTCTGTA_1',
#               'ATACTTCAGAAGAGCA_1',
#               'ATACTTCAGTGATAAC_1',
#               'ATACTTCCAGAAGCGT_1',
#               'ATAGACCCAGGTCCCA_1',
#               'ATATCCTGTGCAGTGA_1',
#               'ATCCACCAGAGGCCAT_1',
#               'ATCCACCTCTGTGCGG_1',
#               'ATCCGTCCACGCGTGT_1',
#               'ATCCTATGTTGATCGT_1',
#               'ATCGCCTGTAATACCC_1',
#               'ATCGTCCTCCAGTACA_1',
#               'ATGAAAGAGACCCGCT_1',
#               'ATGAAAGAGCTGCCTG_1',
#               'ATGACCATCTCATAGG_1',
#               'ATGAGGGGTAGTAAGT_1',
#               'ATGGAGGGTTCAAGTC_1',
#               'ATGGATCGTCGGCCTA_1',
#               'ATTACCTTCGCCTCTA_1',
#               'ATTATCCAGCGCTGAA_1',
#               'ATTATCCCAGTCTTCC_1',
#               'ATTCACTCAACCGTAT_1',
#               'ATTCCATCACCGGAAA_1',
#               'ATTCTTGGTAAGCTCT_1',
#               'ATTTCACAGGCCCGTT_1',
#               'ATTTCACGTTCGGTCG_1',
#               'ATTTCTGGTAGTTACC_1',
#               'CAAAGAACAAGACCGA_1',
#               'CAACAGTTCATTTGTC_1',
#               'CAACGATTCCTAGCCT_1',
#               'CAACGGCCAGGCATGA_1',
#               'CAAGACTTCACACCGG_1',
#               'CAAGCTATCATCACAG_1',
#               'CAAGGGAAGGCCTTCG_1',
#               'CAATACGAGTATGTAG_1',
#               'CAATCGAAGTCATGAA_1',
#               'CAATCGAAGTGTAGTA_1',
#               'CAATGACTCCATTGCC_1',
#               'CACCAAAAGTCTGGTT_1',
#               'CACCAAATCTTGGGCG_1',
#               'CACCGTTAGTTGCCCG_1',
#               'CACGGGTAGCGTTCCG_1',
#               'CACGTTCGTGTTATCG_1',
#               'CACTAAGCACAGTACT_1',
#               'CACTGAAGTTGAGGAC_1',
#               'CACTGGGGTCTGCCTT_1',
#               'CACTTCGTCTCTAAGG_1',
#               'CAGAGCCTCCCTAGGG_1',
#               'CAGATACGTAGCGTAG_1',
#               'CAGCACGAGGCCTTCG_1',
#               'CAGCAGCTCTTCCCAG_1',
#               'CAGCGTGTCAAGCCGC_1',
#               'CAGTTCCAGGTGCATG_1',
#               'CATAAGCCAGAAGCGT_1',
#               'CATACAGGTGGGAGAG_1',
#               'CATACTTGTAACTGCT_1',
#               'CATAGACCAGAGAATT_1',
#               'CATCCACAGAATCGCG_1',
#               'CATCCACGTGCGCTCA_1',
#               'CATCCGTAGGTTCTTG_1',
#               'CATGAGTCAACAAGAT_1',
#               'CATGCAATCGAGATGG_1',
#               'CATGCGGTCTAGCCAA_1',
#               'CATGGTAAGGGTCACA_1',
#               'CATTCTAAGAACTCCT_1',
#               'CATTGAGAGGCAGCTA_1',
#               'CATTGTTTCTCTGCCA_1',
#               'CCACGTTCATAAGCGG_1',
#               'CCATAAGAGTAGAGTT_1',
#               'CCCGAAGGTTGGAGGT_1',
#               'CCCGGAACAATGTGGG_1',
#               'CCCTAACAGAGTAACT_1',
#               'CCCTAACCAGTTCCAA_1',
#               'CCCTCAACATGGGATG_1',
#               'CCCTCAATCTTGGTCC_1',
#               'CCCTGATCAGCCATTA_1',
#               'CCCTGATTCCCTTGTG_1',
#               'CCCTTAGAGATAGCAT_1',
#               'CCGATCTGTAATACCC_1',
#               'CCGATCTTCAATGCAC_1',
#               'CCGATGGAGCCTATCA_1',
#               'CCGGTAGCAAGACGAC_1',
#               'CCGGTAGTCTGAGTCA_1',
#               'CCGTGAGCAAAGGGCT_1',
#               'CCTAACCTCCCATTTA_1',
#               'CCTACGTGTTCCAAAC_1',
#               'CCTATCGAGGGTCTTT_1',
#               'CCTATCGAGTAAGGGA_1',
#               'CCTCAACAGCATATGA_1',
#               'CCTCACAAGCCACTCG_1',
#               'CCTCAGTAGGTGGGTT_1',
#               'CCTCAGTCAACTCCAA_1',
#               'CCTCCAAAGCACTTTG_1',
#               'CCTCTAGGTACTGGGA_1',
#               'CCTCTCCGTTGTTGAC_1',
#               'CCTTCAGGTGATTCTG_1',
#               'CCTTGTGGTCCGAAGA_1',
#               'CGAAGTTTCATGCCCT_1',
#               'CGAATTGAGTGTTGAA_1',
#               'CGAATTGTCGTGGCGT_1',
#               'CGAGAAGGTCTACACA_1',
#               'CGAGTTACAGAAACCG_1',
#               'CGAGTTACAGGACTTT_1',
#               'CGCGTGAGTTGGTAGG_1',
#               'CGGAACCGTCCAGCAC_1',
#               'CGGAATTAGTAATTGG_1',
#               'CGGAGAAAGTAGATCA_1',
#               'CGGGCATAGTCGAATA_1',
#               'CGGGCATGTAGGATAT_1',
#               'CGGGTGTAGTGCAAAT_1',
#               'CGGGTGTCAACAGTGG_1',
#               'CGGGTGTGTTGTACGT_1',
#               'CGGTCAGGTTAGAAAC_1',
#               'CGTAAGTTCACCCTCA_1',
#               'CGTTGGGAGCGCTTCG_1',
#               'CTAACTTAGTAATCCC_1',
#               'CTAACTTTCCGACATA_1',
#               'CTACAGAAGGTCATCT_1',
#               'CTACGGGAGTTCAACC_1',
#               'CTAGACAGTGTCGATT_1',
#               'CTATAGGCATGAATAG_1',
#               'CTATCCGTCTCAGAAC_1',
#               'CTATCTATCATTGCGA_1',
#               'CTCAACCAGAAGCCAC_1',
#               'CTCATCGTCCTAGCCT_1',
#               'CTCATCGTCTCCTGTG_1',
#               'CTCATTAAGATAGCTA_1',
#               'CTCCAACCAAATACGA_1',
#               'CTCCAACGTGAGACCA_1',
#               'CTCCCTCAGTTTCTTC_1',
#               'CTCCTCCCACTTTATC_1',
#               'CTCCTCCTCACCCATC_1',
#               'CTCCTTTGTTACCGTA_1',
#               'CTCCTTTTCTCGGGAC_1',
#               'CTGAATGAGTTCGGTT_1',
#               'CTGAGCGTCACATACG_1',
#               'CTGAGGCCAGAGTTGG_1',
#               'CTGATCCAGGGTACGT_1',
#               'CTGATCCGTCGCTTAA_1',
#               'CTGCAGGAGGAACTAT_1',
#               'CTGCAGGCACATCATG_1',
#               'CTGCATCCACAAGGTG_1',
#               'CTGCATCTCGCGTGAC_1',
#               'CTGCCATTCATGGGAG_1',
#               'CTGGTCTAGGTTAGTA_1',
#               'CTGTATTCATGCACTA_1',
#               'CTGTATTGTCCTTTGC_1',
#               'CTGTCGTCACCTGTCT_1',
#               'CTGTCGTTCGGCATTA_1',
#               'CTGTGGGGTACATTGC_1',
#               'CTTACCGAGTCATGGG_1',
#               'CTTCCGAAGCGGATCA_1',
#               'CTTCCTTAGGATACCG_1',
#               'CTTCGGTCATCCGGTG_1',
#               'CTTCTCTTCTTACCAT_1',
#               'CTTGAGAAGTTGCGCC_1',
#               'CTTGAGAGTGGTCTAT_1',
#               'CTTGATTGTCGCAACC_1',
#               'CTTTCGGTCTCGGTAA_1',
#               'GAAACCTAGGAGATAG_1',
#               'GAAGGACCACGTAGTT_1',
#               'GAAGGGTTCACCATGA_1',
#               'GAAGTAAAGCGCGTTC_1',
#               'GACAGCCGTGGATACG_1',
#               'GACCAATGTGAACCGA_1',
#               'GACCCTTAGACCTCAT_1',
#               'GACCCTTGTTCCAAAC_1',
#               'GACCGTGAGCCGCTTG_1',
#               'GACCTTCTCTTCCACG_1',
#               'GACTGATCACGCGCTA_1',
#               'GACTTCCAGTTACGGG_1',
#               'GACTTCCCAGCTGAAG_1',
#               'GAGACTTGTCGAACAG_1',
#               'GAGAGGTTCTCCCATG_1',
#               'GAGCCTGCACCTGCGA_1',
#               'GAGGCCTTCTACCACC_1',
#               'GAGTGTTCATTGCAAC_1',
#               'GAGTGTTGTATTTCTC_1',
#               'GAGTTGTGTTCCATTT_1',
#               'GATAGAATCGCGTAGC_1',
#               'GATGAGGCAGACACCC_1',
#               'GATGATCCACAAATAG_1',
#               'GATGCTAGTCACCTTC_1',
#               'GATTCTTGTGGAACAC_1',
#               'GCAACATAGCCGATTT_1',
#               'GCACATAAGCTCGTGC_1',
#               'GCACATAGTCATTGCA_1',
#               'GCACATATCGTAGGAG_1',
#               'GCAGCTGGTATGTGTC_1',
#               'GCATCTCAGCGTTAGG_1',
#               'GCATCTCGTTTGGCTA_1',
#               'GCATGATCAATCGCCG_1',
#               'GCCAACGTCCGATTAG_1',
#               'GCCAGGTGTGCACATT_1',
#               'GCCAGGTTCGATTTCT_1',
#               'GCCATGGCAAATAGCA_1',
#               'GCCCAGACAGACTGCC_1',
#               'GCCCAGAGTTGCATCA_1',
#               'GCCGATGGTAAGAACT_1',
#               'GCCGATGTCAGCTGAT_1',
#               'GCCTGTTGTGAACCGA_1',
#               'GCTTCACCATGGGTCC_1',
#               'GGAACCCCAAACGGCA_1',
#               'GGAAGTGTCATTTGGG_1',
#               'GGACGTCAGTCTTCCC_1',
#               'GGATGTTGTATCCCTC_1',
#               'GGCAGTCCATCGAACT_1',
#               'GGGACTCGTATCAGCT_1',
#               'GGGCCATAGATACCAA_1',
#               'GGGCGTTAGCGATGAC_1',
#               'GGGTGAAAGACTCATC_1',
#               'GGTAACTGTACTGTTG_1',
#               'GGTTAACGTATGCAAA_1',
#               'GGTTCTCTCATTTACC_1',
#               'GTAATCGTCAGAACCT_1',
#               'GTACAGTTCACCTGTC_1',
#               'GTAGAGGGTTTAGTCG_1',
#               'GTAGTACAGTTGTCAC_1',
#               'GTATTTCGTATCTTCT_1',
#               'GTCAAACCATTCCTCG_1',
#               'GTCACGGGTTTGAAAG_1',
#               'GTCACTCAGTTGTAGA_1',
#               'GTCACTCTCTCCTACG_1',
#               'GTCATGAGTTCTCGTC_1',
#               'GTCCTCATCCTTCAGC_1',
#               'GTCGTTCAGACGGAAA_1',
#               'GTCGTTCGTGCCTATA_1',
#               'GTCTACCGTCAACATC_1',
#               'GTCTAGAAGTGGTGGT_1',
#               'GTCTGTCAGACGGAAA_1',
#               'GTCTGTCAGTTCTACG_1',
#               'GTCTGTCGTTGGACCC_1',
#               'GTCTGTCTCACTGTTT_1',
#               'GTCTTTACAAAGCGTG_1',
#               'GTGAGGAAGAGAGCGG_1',
#               'GTGAGGATCTCTGCCA_1',
#               'GTGCGTGCACTCAGAT_1',
#               'GTGCGTGCAGTCGCTG_1',
#               'GTGCGTGGTACGCTTA_1',
#               'GTGCGTGTCCAAGAGG_1',
#               'GTGCTTCAGGACAAGA_1',
#               'GTGGGAAGTCCACTTC_1',
#               'GTTACCCGTTGACGGA_1',
#               'GTTATGGAGATAGCAT_1',
#               'GTTCATTAGCCAGTAG_1',
#               'GTTCGCTGTATCCCAA_1',
#               'GTTCTATGTAGTTACC_1',
#               'GTTGCGGTCGCGTTTC_1',
#               'GTTTGGAAGCTTCGTA_1',
#               'TAACGACAGGTAGATT_1',
#               'TAAGCACCAAGTGATA_1',
#               'TAATCTCAGACGAAGA_1',
#               'TAATCTCGTATTTCTC_1',
#               'TAATCTCTCGAACGCC_1',
#               'TACACCCCACTGCTTC_1',
#               'TACCGGGCATCGATAC_1',
#               'TACCTGCAGCAACCAG_1',
#               'TACTGCCCACACCAGC_1',
#               'TACTTCATCACGTCCT_1',
#               'TACTTGTTCAGCGCGT_1',
#               'TAGACCAGTTTCCATT_1',
#               'TAGAGTCAGCGTGTCC_1',
#               'TAGCACATCCCGTTGT_1',
#               'TAGGAGGAGGAGTACC_1',
#               'TAGGGTTAGTAATCCC_1',
#               'TAGGGTTGTACTAGCT_1',
#               'TATACCTTCGTCGCTT_1',
#               'TATATCCTCTCATGCC_1',
#               'TATCCTAAGATACCAA_1',
#               'TATCCTATCGCCAATA_1',
#               'TATCCTATCTTAGGAC_1',
#               'TATCTGTAGGGTTAGC_1',
#               'TATCTGTTCATTGTTC_1',
#               'TATCTGTTCGTCACCT_1',
#               'TATTGCTTCCATAGAC_1',
#               'TATTGGGCACTATCGA_1',
#               'TATTTCGGTTTGCAGT_1',
#               'TCAAGACGTGATACAA_1',
#               'TCAAGACTCCGCCTAT_1',
#               'TCAAGCAAGTCACGAG_1',
#               'TCAAGTGTCGCCCAGA_1',
#               'TCACACCTCTCATGCC_1',
#               'TCACTATAGACTCGAG_1',
#               'TCAGGTAGTTTAGAGA_1',
#               'TCATATCCAACCGACC_1',
#               'TCATATCCACAACCGC_1',
#               'TCATCCGTCCAAGGGA_1',
#               'TCATGAGGTCATTCCC_1',
#               'TCATGAGGTGGAAGTC_1',
#               'TCCACGTAGACCAAGC_1',
#               'TCCATCGTCGTAGCCG_1',
#               'TCCATGCAGAAATTGC_1',
#               'TCCCATGTCCACTGGG_1',
#               'TCCGATCTCAGACCCG_1',
#               'TCCTAATGTCGATGCC_1',
#               'TCCTCGACATGAGGGT_1',
#               'TCCTTTCAGCCATGCC_1',
#               'TCCTTTCTCGCGTGCA_1',
#               'TCGATTTCATGACAGG_1',
#               'TCGATTTTCCCAAGCG_1',
#               'TCGCTTGTCGCAGAGA_1',
#               'TCGGGACCACGCGCAT_1',
#               'TCGGGTGAGACGACGT_1',
#               'TCGGGTGGTAACGTTC_1',
#               'TCGGGTGGTTTAGACC_1',
#               'TCTACATAGAAGTCTA_1',
#               'TCTCAGCCAGGGAGAG_1',
#               'TCTTAGTTCTCGCGTT_1',
#               'TGAACGTTCGATACGT_1',
#               'TGACCCTCATCGATGT_1',
#               'TGACGCGAGCCTCTCT_1',
#               'TGAGGGAAGTGTGTTC_1',
#               'TGAGGTTTCCTTGACC_1',
#               'TGAGTCAAGATCGACG_1',
#               'TGATGCAGTCCGGTCA_1',
#               'TGCACGGTCGGTAACT_1',
#               'TGCAGGCCAAAGAGTT_1',
#               'TGCATCCAGGAGGGTG_1',
#               'TGCGACGTCCTATTGT_1',
#               'TGCTCGTCACATGGTT_1',
#               'TGCTGAATCAAATGCC_1',
#               'TGCTTGCCAGGCTTGC_1',
#               'TGGAACTAGCTCGAAG_1',
#               'TGGAGAGTCACCTACC_1',
#               'TGGCGTGAGGTTCCGC_1',
#               'TGGGATTAGGCAGTCA_1',
#               'TGGGATTTCCACGTAA_1',
#               'TGGGTTATCGAAGCCC_1',
#               'TGGGTTATCGCTTACC_1',
#               'TGGTGATGTACGGCAA_1',
#               'TGTAGACGTCAAGCGA_1',
#               'TGTCCCAAGTTGTAGA_1',
#               'TGTGATGAGGCCTAGA_1',
#               'TGTGGCGAGAGGTTAT_1',
#               'TGTGTGAGTCCCGTGA_1',
#               'TGTTTGTAGTTCCGTA_1',
#               'TTCAATCGTCTAGATC_1',
#               'TTCACGCCAGGACTTT_1',
#               'TTCCTAATCTAGTGAC_1',
#               'TTCCTCTGTCATTCCC_1',
#               'TTCGATTCACCTGCGA_1',
#               'TTCGCTGAGCTATCTG_1',
#               'TTCGCTGCAGCGAGTA_1',
#               'TTCTAACTCATCCTAT_1',
#               'TTCTAGTAGGCTGAAC_1',
#               'TTCTAGTAGTGCTAGG_1',
#               'TTCTAGTCATCTGTTT_1',
#               'TTGAACGCAGCAGTCC_1',
#               'TTGAGTGCAGCAAGAC_1',
#               'TTGAGTGCAGCTCCTT_1',
#               'TTGCCTGTCCTCAGAA_1',
#               'TTGGGCGAGGCTGAAC_1',
#               'TTGGTTTAGTTGCGAG_1',
#               'TTGTGGATCGCCAACG_1',
#               'TTGTGGATCTCCACTG_1',
#               'TTGTTCAAGTCATAGA_1',
#               'TTGTTTGCATGGCACC_1',
#               'TTTACTGGTACGAAAT_1',
#               'TTTATGCCACGACTAT_1',
#               'TTTATGCTCTTCTTCC_1',
#               'TTTCGATGTGAATATG_1',
#               'TTTGGAGGTTCTTAGG_1'],
#              4.0: ['AAACCCAGTCACTCTC_1',
#               'AAACCCATCTTAGCAG_1',
#               'AAAGGGCTCTGCCTCA_1',
#               'AACAAAGGTAAGTTGA_1',
#               'AACCACAAGCCTGCCA_1',
#               'AACCTTTCATATCTGG_1',
#               'AACCTTTTCGGAATGG_1',
#               'AACGTCACAATTAGGA_1',
#               'AAGAACATCGTTGTAG_1',
#               'AAGACAAGTGCAAGAC_1',
#               'AAGACTCCACGCGCTA_1',
#               'AAGGAATGTCCGGTCA_1',
#               'AAGTACCAGCACCGAA_1',
#               'AAGTGAACATCCCACT_1',
#               'AATCACGGTCACCGAC_1',
#               'AATCGTGAGAGAGTTT_1',
#               'ACAACCAGTGATACCT_1',
#               'ACAAGCTAGTCTGTAC_1',
#               'ACAGCCGGTATCTTCT_1',
#               'ACATCGACAGCAGTTT_1',
#               'ACATCGATCCACAAGT_1',
#               'ACCAACACAGACACAG_1',
#               'ACCACAACAAAGGCTG_1',
#               'ACCCAAACAGGATGAC_1',
#               'ACCCTTGAGCTCGTGC_1',
#               'ACCCTTGGTATCCTTT_1',
#               'ACGGTCGCATCATTTC_1',
#               'ACGTACATCGTGCGAC_1',
#               'ACTATCTTCTTCTTCC_1',
#               'ACTCCCACACGTATAC_1',
#               'ACTCCCATCTCTCGAC_1',
#               'ACTGTCCGTCACTCAA_1',
#               'ACTGTGAGTATTGACC_1',
#               'ACTGTGATCCAACCGG_1',
#               'AGAAGTATCCAGGACC_1',
#               'AGACACTTCACAGTGT_1',
#               'AGAGCCCTCACACCGG_1',
#               'AGATGAATCCACAAGT_1',
#               'AGCGATTGTCGTGCCA_1',
#               'AGCGCTGAGCTACAAA_1',
#               'AGCGTATCATCATCTT_1',
#               'AGCTTCCCATCGGTTA_1',
#               'AGCTTCCTCTCTGCTG_1',
#               'AGGAGGTGTTTGCCGG_1',
#               'AGGAGGTTCCATAGAC_1',
#               'AGGCATTCAAGGTCAG_1',
#               'AGGCCACCATCTGGGC_1',
#               'AGTACTGGTACGATCT_1',
#               'ATACTTCCATGGGTTT_1',
#               'ATAGACCCAGCAATTC_1',
#               'ATAGAGACAGCCGTTG_1',
#               'ATAGAGATCAGTGTGT_1',
#               'ATAGAGATCCTCTAGC_1',
#               'ATAGGCTTCACACGAT_1',
#               'ATCACAGCAGTCTGGC_1',
#               'ATCACGATCCAGCACG_1',
#               'ATCGGCGCAGACGATG_1',
#               'ATCGTCCAGCTCCACG_1',
#               'ATGCATGTCCCTCAAC_1',
#               'ATGGGAGAGTTTGCTG_1',
#               'ATGGGAGGTACTGAGG_1',
#               'ATGGGTTTCGGCTGTG_1',
#               'ATGGTTGCATAGGTTC_1',
#               'ATGTCCCAGGTAGCAC_1',
#               'ATGTCCCAGTGATAGT_1',
#               'ATGTCCCTCTGATTCT_1',
#               'ATGTCTTCACCCGTAG_1',
#               'ATTCAGGAGTTCGCAT_1',
#               'ATTCATCCAAGCGAAC_1',
#               'ATTCCCGCACATGTTG_1',
#               'ATTTCACTCCACGAAT_1',
#               'CAAAGAAAGATGATTG_1',
#               'CAAAGAACACAAAGTA_1',
#               'CAACCTCGTATGTCAC_1',
#               'CAACGGCCAATGAACA_1',
#               'CAAGCTAGTCCAGCGT_1',
#               'CAAGGGAAGGCATGGT_1',
#               'CACAACAAGGACGGAG_1',
#               'CACACAAAGAGGCCAT_1',
#               'CACTGGGTCGGTGTTA_1',
#               'CAGAGCCGTCCACAGC_1',
#               'CAGCAATAGGGACCAT_1',
#               'CAGCAGCCAGCAGAAC_1',
#               'CAGCCAGGTCAAGGCA_1',
#               'CAGCCAGGTGCTCCGA_1',
#               'CAGGGCTAGCGATGAC_1',
#               'CAGTTAGGTATGAGAT_1',
#               'CATACTTGTAAGTTGA_1',
#               'CATCAAGTCTCGCAGG_1',
#               'CATCGCTTCATCTACT_1',
#               'CATCGGGAGTGGAAAG_1',
#               'CATGCAATCTCTAGGA_1',
#               'CATGCCTAGTCTGCGC_1',
#               'CATTCATGTAAGACCG_1',
#               'CATTCCGCACGGGTAA_1',
#               'CCACAAACAAACTAAG_1',
#               'CCATAAGCAACGAGGT_1',
#               'CCATAAGGTCACTCGG_1',
#               'CCCATTGAGTAAACTG_1',
#               'CCCTCTCTCGAGAAGC_1',
#               'CCGAACGTCACGGAGA_1',
#               'CCGGTAGAGAGCAAGA_1',
#               'CCGTTCAAGGGTGAGG_1',
#               'CCTGTTGCACAGAGCA_1',
#               'CCTTTGGAGAATTCAG_1',
#               'CGAGGCTCACGCACCA_1',
#               'CGATGGCCAGCTTCGG_1',
#               'CGCAGGTGTAAGATTG_1',
#               'CGCATGGGTGCTGTCG_1',
#               'CGGAGAAGTTAAGCAA_1',
#               'CGGCAGTCAACTGATC_1',
#               'CGGCAGTTCAATCCGA_1',
#               'CGGGTGTGTCACAGAG_1',
#               'CGTAAGTGTAGATTGA_1',
#               'CGTAAGTGTGGGTTGA_1',
#               'CGTCAAAAGGAATCGC_1',
#               'CGTTGGGGTTGTGGAG_1',
#               'CTACATTCAGCAAGAC_1',
#               'CTACGGGTCCGTAGGC_1',
#               'CTACTATAGCCGTTAT_1',
#               'CTACTATGTAGGATAT_1',
#               'CTACTATGTTCACGAT_1',
#               'CTAGACATCAGCCCAG_1',
#               'CTCAAGAGTCCACTCT_1',
#               'CTCAGGGCATAACTCG_1',
#               'CTCCAACAGGCCTTCG_1',
#               'CTCCACAAGAACCCGA_1',
#               'CTCCATGTCATCACAG_1',
#               'CTCCCAAGTCTACGAT_1',
#               'CTCCTCCAGATTCGAA_1',
#               'CTGATCCCACGTAGTT_1',
#               'CTGCCTATCCCTGGTT_1',
#               'CTGCGAGCATGGCCAC_1',
#               'CTGGACGCATATCGGT_1',
#               'CTGGCAGTCGCCATAA_1',
#               'CTGTGAACATGAAGGC_1',
#               'CTTCCGACACAAATGA_1',
#               'GAAACCTCACTAAACC_1',
#               'GAAATGAAGGCTGGAT_1',
#               'GACACGCAGTTTAGGA_1',
#               'GACACGCTCACTTGTT_1',
#               'GACCCAGGTACTTGTG_1',
#               'GACCCAGTCGTTGTAG_1',
#               'GACCCTTGTAGTGCGA_1',
#               'GACTTCCAGCGTGTCC_1',
#               'GACTTCCCACTTGGCG_1',
#               'GAGACTTTCTCTGAGA_1',
#               'GAGGCCTAGTTTCAGC_1',
#               'GAGGGATAGCATTTCG_1',
#               'GAGTTTGGTCGCACGT_1',
#               'GATCCCTGTTTCAGAC_1',
#               'GATCGTACAGAACTCT_1',
#               'GATTCGAGTTGTGCCG_1',
#               'GATTCTTTCCACAAGT_1',
#               'GCACATACACCAGACC_1',
#               'GCACGTGCAACGATCT_1',
#               'GCACGTGGTGAGTCAG_1',
#               'GCACGTGTCCAAGCCG_1',
#               'GCAGCTGAGTCAGCCC_1',
#               'GCATTAGGTCAGGTAG_1',
#               'GCCAGCAGTCAGGTAG_1',
#               'GCCAGTGCAGGACGAT_1',
#               'GCCATGGAGGGACAGG_1',
#               'GCCCAGATCGTTAGTG_1',
#               'GCCGTGAGTACCGGCT_1',
#               'GCCTGTTTCTACCAGA_1',
#               'GCGATCGCATCTCCCA_1',
#               'GCTACAACACACTGGC_1',
#               'GCTACCTAGTGGTCAG_1',
#               'GCTTGGGCAACAAAGT_1',
#               'GCTTTCGTCCGGGACT_1',
#               'GGAATCTCAAGTGCTT_1',
#               'GGAATCTTCGCGCTGA_1',
#               'GGAATGGTCTGGCCAG_1',
#               'GGAGCAACATCTCCCA_1',
#               'GGCAGTCAGCTCCCTT_1',
#               'GGGACTCGTCACGACC_1',
#               'GGGATGACACGGTGTC_1',
#               'GGGTGAAAGGGCCCTT_1',
#               'GGGTTATAGGAGTACC_1',
#               'GGTAACTAGGGTGGGA_1',
#               'GGTAATCTCCGATAAC_1',
#               'GGTAGAGCACAATGAA_1',
#               'GTAATGCAGTCGAGGT_1',
#               'GTACAGTCAGGTTCCG_1',
#               'GTCAAGTAGTTCATGC_1',
#               'GTCAAGTCAAGTTCGT_1',
#               'GTCCCATTCCTCTAGC_1',
#               'GTCGCGAGTTTGGGTT_1',
#               'GTCTCACAGCACTCGC_1',
#               'GTCTCACCAAAGTATG_1',
#               'GTGACGCAGCATTGAA_1',
#               'GTGAGCCGTCCTTAAG_1',
#               'GTGAGGAAGCACTCGC_1',
#               'GTGCAGCGTTCGTTCC_1',
#               'GTGCTGGGTATGTGTC_1',
#               'GTGCTTCCAGATACCT_1',
#               'GTGGGAAGTGGCTGAA_1',
#               'GTTAGACTCAACTACG_1',
#               'GTTAGTGAGACTGTTC_1',
#               'GTTCCGTTCTGACAGT_1',
#               'GTTCTATCAGGACATG_1',
#               'GTTGCGGGTCCGAAAG_1',
#               'GTTGCTCCATAATGCC_1',
#               'GTTGTGACATAGGAGC_1',
#               'GTTGTGAGTACGAGTG_1',
#               'GTTTGGAAGATGACAT_1',
#               'TAACACGAGAGTCGAC_1',
#               'TACACCCCAGAATGTA_1',
#               'TACAGGTTCTAACGCA_1',
#               'TACGCTCGTGAGTCAG_1',
#               'TACTTACAGTCTAGAA_1',
#               'TAGGAGGTCTATGCCC_1',
#               'TAGGTACCAACACACT_1',
#               'TAGGTTGCAGTTTCGA_1',
#               'TATCGCCTCTAACACG_1',
#               'TATCTGTCATTCCTAT_1',
#               'TATCTTGGTATTGACC_1',
#               'TATTCCAGTGAATTAG_1',
#               'TATTCCATCTGGACCG_1',
#               'TATTGCTCACCACTGG_1',
#               'TATTGCTGTTCCGCGA_1',
#               'TCACAAGCACAATGTC_1',
#               'TCACACCGTTCGATTG_1',
#               'TCACTCGGTAGAATAC_1',
#               'TCAGCAAGTCGTCATA_1',
#               'TCAGCAAGTTTCGGCG_1',
#               'TCAGCCTCATTCTCCG_1',
#               'TCAGGGCTCCACGTAA_1',
#               'TCAGTCCGTCACAGTT_1',
#               'TCAGTTTTCGGTTGTA_1',
#               'TCATACTGTGACATCT_1',
#               'TCATGCCAGGTGGGTT_1',
#               'TCATTACGTTCGAAGG_1',
#               'TCATTGTTCTGAATCG_1',
#               'TCCACCACATGGAACG_1',
#               'TCCACCAGTTAAGCAA_1',
#               'TCCACCATCTAGCATG_1',
#               'TCCACGTAGTTCAACC_1',
#               'TCCCACACAATGACCT_1',
#               'TCCCATGTCCAACTGA_1',
#               'TCCGGGAAGCTGGAGT_1',
#               'TCCGTGTCACAGTGTT_1',
#               'TCCTCCCCATCTCCCA_1',
#               'TCCTCTTTCATTTGCT_1',
#               'TCCTCTTTCTGGTGGC_1',
#               'TCCTGCACACCATTCC_1',
#               'TCCTGCACAGACAAGC_1',
#               'TCCTGCATCGCCGAAC_1',
#               'TCGACCTGTCGCATGC_1',
#               'TCGGGCAAGTCCGTCG_1',
#               'TCGGGCAGTGGCTACC_1',
#               'TCGTGCTTCCCTTTGG_1',
#               'TCGTGGGGTTTGCCGG_1',
#               'TCTACCGTCCGTATGA_1',
#               'TCTATCACAGCATACT_1',
#               'TCTCCGACAAAGGCAC_1',
#               'TGAGACTCACACACGC_1',
#               'TGCACGGTCGGTCATA_1',
#               'TGCAGTAGTTACTCAG_1',
#               'TGGAGAGGTGAATTAG_1',
#               'TGGAGGAGTCCTGGGT_1',
#               'TGGATCAAGGGCTAAC_1',
#               'TGGGATTGTGGTCTTA_1',
#               'TGGGCGTTCAGACAAA_1',
#               'TGGTGATTCGTGGTAT_1',
#               'TGGTTAGAGTACTGTC_1',
#               'TGTCCCAAGACGCTCC_1',
#               'TGTGAGTGTGATAGAT_1',
#               'TGTGTGATCCATTTAC_1',
#               'TGTTACTAGCCGAACA_1',
#               'TGTTCATAGGAAGTCC_1',
#               'TGTTCCGGTGCTGCAC_1',
#               'TGTTCCGTCTTTCCGG_1',
#               'TGTTCTAGTGGATACG_1',
#               'TGTTTGTCAAGGTCTT_1',
#               'TTAATCCCACTCTAGA_1',
#               'TTACCATTCGCGTGCA_1',
#               'TTCAGGAAGATGTAGT_1',
#               'TTCGATTCATTGCCTC_1',
#               'TTCGCTGGTCCCGTGA_1',
#               'TTCTAGTTCCGCGATG_1',
#               'TTCTTCCTCGAGTTGT_1',
#               'TTGATGGAGAGAGGTA_1',
#               'TTGATGGCAGTTAAAG_1',
#               'TTGCCTGAGCCTTCTC_1',
#               'TTGCCTGTCATGCCCT_1',
#               'TTGTTGTTCCTCTAAT_1',
#               'TTGTTTGCAAGTGGAC_1',
#               'TTTATGCTCGCGATCG_1',
#               'TTTCACACAATGGCCC_1',
#               'TTTCACATCAAGTGTC_1',
#               'TTTCAGTGTCAGTCCG_1',
#               'TTTCGATTCTCATTAC_1',
#               'TTTGACTCAACCGTAT_1',
#               'AAACGAAGTATCGTAC_3',
#               'AAACGCTAGCAACTCT_3',
#               'AACAACCCAGAAACCG_3',
#               'AACACACAGTTAACAG_3',
#               'AACCACACATCAGTCA_3',
#               'AAGAACAGTGCCGGTT_3',
#               'AAGATAGAGGCACTCC_3',
#               'AAGATAGAGTAATCCC_3',
#               'AAGCGAGTCTCAGTCC_3',
#               'AAGCGTTTCCGGCAAC_3',
#               'AAGGAATGTGGCAGAT_3',
#               'AATGCCAAGCTCCACG_3',
#               'ACAGAAAAGCATGATA_3',
#               'ACATCCCAGTATGGAT_3',
#               'ACATCCCGTCGAAGCA_3',
#               'ACCACAAGTATTAAGG_3',
#               'ACCCAAATCAGTGCGC_3',
#               'ACCCTCATCCCAGCGA_3',
#               'ACCTGTCTCTGCGTCT_3',
#               'ACGATGTCATGGAATA_3',
#               'ACGTCCTCATACAGCT_3',
#               'ACGTCCTGTCGCTTGG_3',
#               'ACTCTCGTCTCGGCTT_3',
#               'ACTGATGGTATCACCA_3',
#               'ACTGCAATCGCGTGCA_3',
#               'ACTTCCGCATTGCTGA_3',
#               'ACTTTGTGTCCTGGTG_3',
#               'AGAACAACAGGCGTTC_3',
#               'AGAAGCGGTCGATTTG_3',
#               'AGACAGGGTTGTATGC_3',
#               'AGAGAGCGTACGTAGG_3',
#               'AGAGCAGTCCTACACC_3',
#               'AGATAGATCAAAGAAC_3',
#               'AGATCGTCATCGATCA_3',
#               'AGCATCACAACACGTT_3',
#               'AGCATCACACATGAAA_3',
#               'AGCCAGCAGTATAGAC_3',
#               'AGCGTATCAGTGACCC_3',
#               'AGCGTATGTCATGACT_3',
#               'AGCTCAATCGTTCCCA_3',
#               'AGCTTCCGTATCATGC_3',
#               'AGGACGATCTTCGGTC_3',
#               'AGGCATTCATACCGTA_3',
#               'AGGGCCTAGACGGAAA_3',
#               'AGGGTCCAGAGGTCAC_3',
#               'AGGTCATGTCGCGTTG_3',
#               'AGGTCTAGTAAGACCG_3',
#               'AGGTTACAGGATGCGT_3',
#               'AGTAACCAGTAAAGCT_3',
#               'AGTACTGAGAGTCGAC_3',
#               'AGTACTGGTTTAGAGA_3',
#               'AGTAGTCAGGGTGGGA_3',
#               'AGTCAACCAACAGATA_3',
#               'AGTCAACTCGATTGAC_3',
#               'AGTCTCCAGCCTTCTC_3',
#               'AGTCTCCCAGTTTCGA_3',
#               'ATAGACCAGACTACCT_3',
#               'ATAGAGACACTCCTGT_3',
#               'ATAGAGAGTAGTTCCA_3',
#               'ATCACGATCGCTGCGA_3',
#               'ATCACGATCGGTGTAT_3',
#               'ATCAGGTCAGCGACCT_3',
#               'ATCATTCAGTATGAGT_3',
#               'ATCGATGAGTCTGTAC_3',
#               'ATCGCCTTCCACGTAA_3',
#               'ATCGGATGTGCGCTCA_3',
#               'ATCGTCCTCTATCACT_3',
#               'ATCTCTAGTTCATCTT_3',
#               'ATGAAAGAGAGCAAGA_3',
#               'ATGACCAGTCCGCAGT_3',
#               'ATGCCTCGTAGGCTCC_3',
#               'ATGCCTCGTGTTTCTT_3',
#               'ATGGATCAGACCATGG_3',
#               'ATGTCCCTCTGCCCTA_3',
#               'ATTCACTGTGGGTATG_3',
#               'ATTCACTGTGTGCCTG_3',
#               'ATTCCATCAACGAGGT_3',
#               'CAACAACAGTAGCCAG_3',
#               'CAACAACGTTCCCACT_3',
#               'CAAGAGGAGTCATTGC_3',
#               'CAAGGGAAGTCACTGT_3',
#               'CACACAATCACCACAA_3',
#               'CACAGATGTATCGAAA_3',
#               'CACGTGGTCGGCTGAC_3',
#               'CACTTCGGTAAGATCA_3',
#               'CAGATCAGTGCACGCT_3',
#               'CAGATTGAGTTGGGAC_3',
#               'CAGTTCCAGGTCCCGT_3',
#               'CATCCACAGACCATGG_3',
#               'CATCCCACATCCCACT_3',
#               'CATCGCTGTTATTCCT_3',
#               'CATGCAAGTGTCTAAC_3',
#               'CATGCAATCTCAAAGC_3',
#               'CATGCCTAGGTAATCA_3',
#               'CATGCCTTCCCGTTCA_3',
#               'CATGCTCAGGCCTAGA_3',
#               'CATTCTAGTTCTCGCT_3',
#               'CATTGCCCACCAGTAT_3',
#               'CATTGCCGTTATTCTC_3',
#               'CATTGTTTCGCCAATA_3',
#               'CCAAGCGAGGGTGAGG_3',
#               'CCACAAAAGCCATTTG_3',
#               'CCACACTAGTCAGCCC_3',
#               'CCACACTCAGCTATAC_3',
#               'CCACCATGTACGCTAT_3',
#               'CCACCATTCCATACAG_3',
#               'CCACCATTCCTCACTG_3',
#               'CCACGAGCACTGTCCT_3',
#               'CCACGAGCAGTGCGCT_3',
#               'CCACTTGAGCCGTCGT_3',
#               'CCCTCAACAGATACCT_3',
#               'CCGGGTAGTCCACAGC_3',
#               'CCGTAGGAGTCAGAGC_3',
#               'CCGTGAGCATAGGTAA_3',
#               'CCGTGAGGTGTCGATT_3',
#               'CCTATCGTCTGGAAGG_3',
#               'CCTCATGGTTAGGAGC_3',
#               'CCTCCTCAGATTAGTG_3',
#               'CCTCCTCAGTAGATCA_3',
#               'CCTCTAGAGCACTGGA_3',
#               'CCTCTAGCATCATCCC_3',
#               'CCTGCATGTACCGGCT_3',
#               'CCTTGTGTCGACATTG_3',
#               'CGAAGGATCGAGAGAC_3',
#               'CGAAGTTCAGTGTATC_3',
#               'CGAGGAAAGTGCGCTC_3',
#               'CGAGTGCGTTCCGTTC_3',
#               'CGATCGGGTTCAAAGA_3',
#               'CGATGCGAGTTAGTGA_3',
#               'CGCAGGTCAGCTCGGT_3',
#               'CGCAGGTCATGACGGA_3',
#               'CGGCAGTCAAGTTCCA_3',
#               'CGGCAGTGTCGTCTCT_3',
#               'CGGGTGTAGGACCCAA_3',
#               'CGTAAGTGTGACTGTT_3',
#               'CTAACCCAGGATGGCT_3',
#               'CTAAGTGAGCTGGTGA_3',
#               'CTACAGAGTGATAGTA_3',
#               'CTACCTGAGTGGGAAA_3',
#               'CTACCTGTCGTGACTA_3',
#               'CTACCTGTCTTAGGAC_3',
#               'CTAGGTAAGAGTCACG_3',
#               'CTAGGTATCCAACCGG_3',
#               'CTATCCGCACAACATC_3',
#               'CTATCCGCATCATCCC_3',
#               'CTATCTACACTCAGAT_3',
#               'CTCAAGAGTTATAGCC_3',
#               'CTCAGTCCAAACACGG_3',
#               'CTCCTTTGTCGTATTG_3',
#               'CTGCAGGGTTTACTGG_3',
#               'CTGCGAGGTTACCTGA_3',
#               'CTGTACCTCTAAGCCA_3',
#               'CTGTAGAGTAGCGCCT_3',
#               'CTGTATTGTCGAAGCA_3',
#               'CTGTGAACAGCATCTA_3',
#               'CTTCAATAGACTACCT_3',
#               'CTTCTAACAGTAGTGG_3',
#               'CTTGATTTCCTATTGT_3',
#               'CTTTCAAGTGACCGAA_3',
#               'GAATCACGTTGTTGCA_3',
#               'GACAGCCTCCCAAGCG_3',
#               'GACCCTTAGCTGAGCA_3',
#               'GACCCTTGTCGGATTT_3',
#               'GACCGTGCACCGGTCA_3',
#               'GACTATGAGACTACGG_3',
#               'GACTATGCAATAGTCC_3',
#               'GACTGATCACAGTGAG_3',
#               'GACTTCCGTCATGCAT_3',
#               'GAGACTTCAATGCTCA_3',
#               'GAGACTTTCTCGCCTA_3',
#               'GAGAGGTCAATCCTAG_3',
#               'GAGATGGGTTTCGCTC_3',
#               'GAGCCTGGTGGGCTTC_3',
#               'GAGGGATGTGGTCTAT_3',
#               'GAGGGTATCTCACTCG_3',
#               'GATCAGTCAGACCATT_3',
#               'GATCAGTTCACGGACC_3',
#               'GATGACTAGACCAGCA_3',
#               'GATGAGGAGTAGACCG_3',
#               'GATGATCTCCTTTGAT_3',
#               'GATGCTACAAGCTGCC_3',
#               'GATTCTTCATGCACTA_3',
#               'GCACGGTAGGGTGAGG_3',
#               'GCAGGCTGTGTAGCAG_3',
#               'GCCAACGTCCACGGGT_3',
#               'GCCAGGTGTTGCTTGA_3',
#               'GCCATGGTCGCACTCT_3',
#               'GCCATTCCATCTCATT_3',
#               'GCCGTGAAGACTTGTC_3',
#               'GCCGTGATCTGTCGTC_3',
#               'GCCTGTTAGCGACTGA_3',
#               'GCGGAAACACGCTGAC_3',
#               'GCGTTTCCATCACCAA_3',
#               'GCTACAAGTGCGAGTA_3',
#               'GGAGAACTCTTGGCTC_3',
#               'GGAGATGAGAGGTTTA_3',
#               'GGATGTTGTTCTATCT_3',
#               'GGCGTCAGTAACTAAG_3',
#               'GGCTTGGAGATAACGT_3',
#               'GGCTTGGTCAACCTTT_3',
#               'GGGAAGTCAGATTAAG_3',
#               'GGGATGATCGTGCGAC_3',
#               'GGGTAGAAGACGACGT_3',
#               'GGGTATTAGGGCTTCC_3',
#               'GGGTCACCACGTCGGT_3',
#               'GGGTCTGTCAACGCTA_3',
#               'GGGTGAAAGACGGTCA_3',
#               'GGGTTATCATTCTCCG_3',
#               'GGTAACTTCTTCACGC_3',
#               'GGTAATCCATCGGCCA_3',
#               'GGTAATCGTAGTGCGA_3',
#               'GGTAGAGGTTACCTTT_3',
#               'GGTTGTAAGCCAACCC_3',
#               'GTACAACAGGAATGTT_3',
#               'GTAGGAGAGCTCACTA_3',
#               'GTATTTCCATCCAACA_3',
#               'GTCAAACAGGATTCCT_3',
#               'GTCACGGTCTTTGATC_3',
#               'GTCAGCGAGTTGGACG_3',
#               'GTCATCCGTTTCCCAC_3',
#               'GTCGAATCACACAGCC_3',
#               'GTCGCGAAGTGGTCAG_3',
#               'GTCGTTCTCATTGCCC_3',
#               'GTCTAGACAACGTATC_3',
#               'GTCTAGATCAAACCTG_3',
#               'GTGAGGAGTGTAGCAG_3',
#               'GTGGAGAAGCGCCATC_3',
#               'GTGTAACGTTGCCGCA_3',
#               'GTGTTAGCAGGAGGAG_3',
#               'GTTCATTAGCCAGTAG_3',
#               'GTTCATTGTTAGTCGT_3',
#               'GTTCTATGTTGGGACA_3',
#               'GTTGAACAGTGCAAAT_3',
#               'GTTGTCCCATATGAAG_3',
#               'GTTGTCCGTACAAGCG_3',
#               'TAAGCCATCCACAGGC_3',
#               'TAATTCCCAGCTGCCA_3',
#               'TAATTCCTCAACGTGT_3',
#               'TACAGGTCAGTTCCAA_3',
#               'TACCCACCAGCCGGTT_3',
#               'TACCGAATCATGGTAC_3',
#               'TACCTGCAGCAGGCTA_3',
#               'TACTGCCAGCTGACTT_3',
#               'TACTTACAGAGGATGA_3',
#               'TAGCACAAGCACGATG_3',
#               'TAGGAGGTCATTTACC_3',
#               'TAGGGTTTCTGTGCTC_3',
#               'TAGGTTGGTCATCCGG_3',
#               'TAGTGCAAGGCGTCCT_3',
#               'TATCGCCTCCCATTTA_3',
#               'TATTCCAGTTGACTAC_3',
#               'TATTGCTAGTGCACAG_3',
#               'TCAATTCTCTATCACT_3',
#               'TCACGCTGTCTGTAGT_3',
#               'TCACTATGTTCTCCTG_3',
#               'TCAGTTTCACTGAGTT_3',
#               'TCATGCCTCCCTAGGG_3',
#               'TCATGGAAGATTACCC_3',
#               'TCATGTTAGTCAAGCG_3',
#               'TCATTTGAGGGCTGAT_3',
#               'TCCACCATCTGCAGCG_3',
#               'TCCCACACAAGTGCAG_3',
#               'TCCCAGTGTTACCGTA_3',
#               'TCCGAAATCAGACCGC_3',
#               'TCCGGGACAACTCCAA_3',
#               'TCCGGGATCTACCTTA_3',
#               'TCGAACAAGTTTCAGC_3',
#               'TCGAAGTGTCGCATGC_3',
#               'TCGACGGTCGATACGT_3',
#               'TCGCTCAAGTCATGAA_3',
#               'TCGTCCAAGTATAGAC_3',
#               'TCTGCCAGTTCTATCT_3',
#               'TCTGTCGTCATGGATC_3',
#               'TCTTCCTAGAGTATAC_3',
#               'TGAATGCAGTTAGTGA_3',
#               'TGAATGCCACCTGTCT_3',
#               'TGACTCCCAATGTGGG_3',
#               'TGAGACTAGAGAAGGT_3',
#               'TGAGACTTCCTCTCTT_3',
#               'TGAGTCAAGAGTGACC_3',
#               'TGAGTCAAGTGATAGT_3',
#               'TGATTCTTCTAACGGT_3',
#               'TGCAGATTCACTGGGC_3',
#               'TGCAGGCCAATACAGA_3',
#               'TGCGACGCACGATAGG_3',
#               'TGCGGCAAGCTAAATG_3',
#               'TGCTCGTCATATCTCT_3',
#               'TGGAGAGAGTGTGTTC_3',
#               'TGGAGAGTCACAGTGT_3',
#               'TGGAGGAAGACATAAC_3',
#               'TGGATGTAGACACACG_3',
#               'TGGATGTTCTAGAACC_3',
#               'TGGGCTGCAGACATCT_3',
#               'TGGTTAGCAATATCCG_3',
#               'TGTGCGGTCGACGAGA_3',
#               'TGTTACTCAGAAATTG_3',
#               'TGTTCTATCGGTGAAG_3',
#               'TTACAGGCACGACAAG_3',
#               'TTACCATAGGTCACCC_3',
#               'TTACGCCGTGCAAGAC_3',
#               'TTACGTTTCAGACCTA_3',
#               'TTAGGGTAGGACTATA_3',
#               'TTCACCGGTGTCATGT_3',
#               'TTCATTGAGACCAACG_3',
#               'TTCATTGCAATAACGA_3',
#               'TTGGGATAGCTCTGTA_3',
#               'TTGGGATCACTAGGCC_3',
#               'TTGTGGACAAACACCT_3',
#               'TTGTTGTGTGTCTCCT_3',
#               'TTTACTGGTCTAGATC_3',
#               'TTTCATGAGAGGCGGA_3',
#               'TTTCATGAGGCGACAT_3',
#               'TTTGGTTTCCGTGGGT_3'],
#              6.0: ['AAACCCATCCTGCTAC_1',
#               'AAACGCTGTCTACATG_1',
#               'AAAGGGCTCTTGGCTC_1',
#               'AAAGGTAAGGAGCTGT_1',
#               'AAAGTCCTCAACTGGT_1',
#               'AACAAAGTCCCATTTA_1',
#               'AACAACCCATCCTAAG_1',
#               'AACAACCTCACCTCGT_1',
#               'AACAGGGAGCTCGCAC_1',
#               'AACCACAAGTGGTGGT_1',
#               'AACCATGTCGAAGTGG_1',
#               'AACGGGAAGGTAGGCT_1',
#               'AACTTCTCAGCATCTA_1',
#               'AAGATAGCAACCGTGC_1',
#               'AAGGAATGTGCCCTTT_1',
#               'AAGTTCGTCTTCCCGA_1',
#               'AATAGAGGTACGGGAT_1',
#               'AATCGACTCTTGAACG_1',
#               'AATGACCAGGTAAGAG_1',
#               'AATGCCACAAGAGTGC_1',
#               'AATGGCTTCATAGCAC_1',
#               'ACAAGCTCATAGCTGT_1',
#               'ACAAGCTGTTAAACAG_1',
#               'ACACGCGAGGGTAGCT_1',
#               'ACAGCCGGTCAACCTA_1',
#               'ACAGGGACAATACGAA_1',
#               'ACATCCCTCGTTCTCG_1',
#               'ACATTTCAGATCACCT_1',
#               'ACATTTCTCATGTCAG_1',
#               'ACCAAACCAGTGGTGA_1',
#               'ACCAAACTCTAGCAAC_1',
#               'ACCAACAAGCCTTTGA_1',
#               'ACCCAAAAGTCGGGAT_1',
#               'ACCCAAATCGTGAGAG_1',
#               'ACCCTTGCAATGTCAC_1',
#               'ACCTGAACATGCAGCC_1',
#               'ACGGTTAAGGGAGATA_1',
#               'ACTGTCCTCTCTCGAC_1',
#               'ACTGTGATCAGGACAG_1',
#               'ACTGTGATCGAAGAAT_1',
#               'ACTTAGGAGCTACAAA_1',
#               'ACTTAGGGTACAGGTG_1',
#               'ACTTCGCCAGCGTTTA_1',
#               'AGAAATGGTCTCAGGC_1',
#               'AGAACCTTCTTCACGC_1',
#               'AGACCCGCATGCAGGA_1',
#               'AGAGAGCCACTGGAAG_1',
#               'AGAGAGCGTTCTCACC_1',
#               'AGATGAAGTTGCAACT_1',
#               'AGCATCACACCAGCTG_1',
#               'AGCATCAGTAATTGGA_1',
#               'AGCCACGAGAAAGCGA_1',
#               'AGCCACGTCTTCCCGA_1',
#               'AGCCAGCCAAAGGCGT_1',
#               'AGCCAGCGTACCCGAC_1',
#               'AGCGCTGGTTGTAGCT_1',
#               'AGCGTATTCCATCTAT_1',
#               'AGCGTCGGTAAGAACT_1',
#               'AGCTACACAGCAGACA_1',
#               'AGCTACAGTTGTATGC_1',
#               'AGCTCAACAGCCGTTG_1',
#               'AGGAAATGTGCTCGTG_1',
#               'AGGACTTGTGGGCTTC_1',
#               'AGGAGGTCAAGACTGG_1',
#               'AGGCATTAGTCGGGAT_1',
#               'AGGCCACAGCTAGAAT_1',
#               'AGGGCTCAGATAACAC_1',
#               'AGGGCTCTCGGTGAAG_1',
#               'AGGGTCCAGTTGGGAC_1',
#               'AGGGTCCTCGTCGACG_1',
#               'AGGGTGATCAGTCCGG_1',
#               'AGGTAGGCAGAAACCG_1',
#               'AGGTCATGTGTGTACT_1',
#               'AGGTCTATCGCTTTAT_1',
#               'AGGTGTTTCACCGCTT_1',
#               'AGGTTACTCTGTACAG_1',
#               'AGTCAACGTCATACCA_1',
#               'AGTCTCCTCTTGGAAC_1',
#               'ATACCTTCATCGGATT_1',
#               'ATACTTCCAAGTTCGT_1',
#               'ATAGGCTCAGGGATAC_1',
#               'ATATCCTAGCACCGTC_1',
#               'ATCAGGTCAAGCCCAC_1',
#               'ATCATTCCACTACTTT_1',
#               'ATCGATGAGATTAGCA_1',
#               'ATCGCCTTCTTGGGCG_1',
#               'ATCGGCGGTCATGCAT_1',
#               'ATCGTAGTCTCGGCTT_1',
#               'ATCGTGAGTAGACAGC_1',
#               'ATGAAAGAGGGAGGTG_1',
#               'ATGACCATCGTAGAGG_1',
#               'ATGGATCAGACGCATG_1',
#               'ATGGTTGGTCCAGCCA_1',
#               'ATGGTTGTCAAAGGAT_1',
#               'ATGTCCCTCGAGTTGT_1',
#               'ATGTCTTCATGTCGTA_1',
#               'ATGTCTTGTAATGTGA_1',
#               'ATTACTCCAGTCAACT_1',
#               'ATTCCTATCGACCTAA_1',
#               'ATTCCTATCGCGGTAC_1',
#               'ATTCTACCACGCGCTA_1',
#               'ATTGTTCTCTGGCCGA_1',
#               'ATTTCACCATCGAGCC_1',
#               'ATTTCTGAGGCTATCT_1',
#               'ATTTCTGCAGCGTAGA_1',
#               'CAACAGTTCGTCAGAT_1',
#               'CAACCAATCTACTGCC_1',
#               'CAACGATGTAAGCTCT_1',
#               'CAACGGCAGATCCAAA_1',
#               'CAAGCTAAGTATGGCG_1',
#               'CAAGGGAGTGTATCCA_1',
#               'CAATACGAGTTGGACG_1',
#               'CAATTTCAGGTTGAGC_1',
#               'CACACAAGTACGGTTT_1',
#               'CACAGATTCCACGAAT_1',
#               'CACCAAAGTCAACATC_1',
#               'CACCGTTGTGAAGCTG_1',
#               'CACCGTTTCAAGATAG_1',
#               'CACGAATCAGTCAGAG_1',
#               'CACGTGGCACGGCGTT_1',
#               'CACGTTCAGCATGTTC_1',
#               'CACTAAGGTCTTCGAA_1',
#               'CACTAAGGTGTTTGCA_1',
#               'CACTGAAAGAAGGGAT_1',
#               'CACTGGGAGCAACTTC_1',
#               'CACTGTCGTCTTTCAT_1',
#               'CAGATACCACTACCGG_1',
#               'CAGATACGTGCGCTCA_1',
#               'CAGATCAAGGTTCTTG_1',
#               'CAGCAATAGGATGTTA_1',
#               'CAGCACGAGGTAAACT_1',
#               'CAGCCAGCACTCGATA_1',
#               'CAGCCAGTCGATCCAA_1',
#               'CAGGTATTCTAGATCG_1',
#               'CAGTTAGAGGGCGAGA_1',
#               'CATCCCAAGGTCGTGA_1',
#               'CATCCCAGTGTATTGC_1',
#               'CATCCGTCAGTCAGAG_1',
#               'CATCGGGTCAAGAAAC_1',
#               'CATCGTCAGTTGTCGT_1',
#               'CATGCAATCTTAATCC_1',
#               'CATGGATGTGTTCCAA_1',
#               'CATTCATGTGCCGAAA_1',
#               'CATTCCGAGAGCATAT_1',
#               'CATTGTTTCTCCAAGA_1',
#               'CCACGTTAGAACGCGT_1',
#               'CCATAAGAGGTCGTAG_1',
#               'CCATCACAGTAGAGTT_1',
#               'CCCGAAGTCACTGGGC_1',
#               'CCCGGAAGTAGGCAGT_1',
#               'CCCTCTCAGTTTCAGC_1',
#               'CCCTGATGTATTCTCT_1',
#               'CCGATCTCAATGCAAA_1',
#               'CCGATGGTCCGAACGC_1',
#               'CCGGTAGTCAAGCCCG_1',
#               'CCGGTGAGTAAGTTAG_1',
#               'CCTAAGATCGACCATA_1',
#               'CCTCAACCATTGTACG_1',
#               'CCTCAACTCACCGGTG_1',
#               'CCTCACACACATATGC_1',
#               'CCTCCAAAGTGACCTT_1',
#               'CCTGTTGTCGCCGAGT_1',
#               'CCTTCAGAGTGTAGAT_1',
#               'CCTTGTGAGTACCATC_1',
#               'CCTTGTGTCGACCTAA_1',
#               'CCTTTGGCATGAAGGC_1',
#               'CGAAGGATCGACGAGA_1',
#               'CGACAGCGTTCACGAT_1',
#               'CGAGAAGGTATGCGTT_1',
#               'CGAGTTACAGTCAGCC_1',
#               'CGATGCGAGGGCTAAC_1',
#               'CGATGCGTCGATACGT_1',
#               'CGATGGCAGTTGCCTA_1',
#               'CGCAGGTGTTAGGCTT_1',
#               'CGCATAAAGAAATCCA_1',
#               'CGCATAAAGTCTACCA_1',
#               'CGCATAACACCGAATT_1',
#               'CGCGTGAGTGTAGCAG_1',
#               'CGGAATTCAGGTTCGC_1',
#               'CGGAGAAGTGCCCACA_1',
#               'CGGGTCAAGAAGGTAG_1',
#               'CGGGTCAGTAGCTTGT_1',
#               'CGGGTGTAGGGATCTG_1',
#               'CGTAAGTCATCGTTCC_1',
#               'CGTAGTAGTGTGGTCC_1',
#               'CGTGATATCTTCCCAG_1',
#               'CGTGCTTAGACTACCT_1',
#               'CGTGCTTTCATGACAC_1',
#               'CGTTAGATCCTGTACC_1',
#               'CGTTCTGTCTCATAGG_1',
#               'CGTTGGGCAACGATTC_1',
#               'CTAACCCGTGCATTAC_1',
#               'CTAACTTCACCTAAAC_1',
#               'CTAAGTGCAATGAGCG_1',
#               'CTAAGTGGTACAACGG_1',
#               'CTACAGATCTGGGCCA_1',
#               'CTACCCAGTATGTCTG_1',
#               'CTAGGTAGTATTAAGG_1',
#               'CTATCCGAGCGTTGTT_1',
#               'CTATCCGCACCTATCC_1',
#               'CTATCCGTCTTAAGGC_1',
#               'CTCAATTCAATTGAAG_1',
#               'CTCAATTTCGCTCTCA_1',
#               'CTCATCGCATATCTGG_1',
#               'CTCATTACAACCAATC_1',
#               'CTCATTACAAGACGAC_1',
#               'CTCATTACAGGACTTT_1',
#               'CTCCAACGTACTCGTA_1',
#               'CTCCCTCGTATTAAGG_1',
#               'CTCCGATGTAGTATAG_1',
#               'CTCCTCCTCGATTCCC_1',
#               'CTCTCAGAGCCTCACG_1',
#               'CTCTCAGTCCTAGAGT_1',
#               'CTCTCAGTCGAACTCA_1',
#               'CTGAATGCAATGTGGG_1',
#               'CTGAGCGAGCACGATG_1',
#               'CTGATCCAGATCACTC_1',
#               'CTGCAGGGTGGGCTTC_1',
#               'CTGCCTAAGCCGTCGT_1',
#               'CTGCCTACATGGGCAA_1',
#               'CTGGACGCATCATGAC_1',
#               'CTGTACCAGACCATGG_1',
#               'CTGTACCGTACATACC_1',
#               'CTTAGGAAGTCGGCCT_1',
#               'CTTAGGATCCCATGGG_1',
#               'CTTGATTCACCTGCTT_1',
#               'CTTTCAATCATTGCGA_1',
#               'CTTTCGGCAACCACAT_1',
#               'GAAGAATAGTCATGGG_1',
#               'GAAGCGAAGAGTCACG_1',
#               'GAAGCGAAGCGAAACC_1',
#               'GAAGGGTCAGACGGAT_1',
#               'GAATCGTCACCAGTTA_1',
#               'GACCGTGTCACAGTGT_1',
#               'GACGTTAAGTACTCGT_1',
#               'GACGTTATCACAACCA_1',
#               'GAGATGGAGGCCGCTT_1',
#               'GAGGCAACATAGTCGT_1',
#               'GAGGGATGTATTTCTC_1',
#               'GAGGGATGTCCGGATC_1',
#               'GAGTCATAGCGGCTCT_1',
#               'GAGTCATCAGAGTCAG_1',
#               'GAGTGTTGTAACGGTG_1',
#               'GAGTGTTTCAATCTTC_1',
#               'GATAGCTCACCACTGG_1',
#               'GATAGCTGTACCCAGC_1',
#               'GATCACAAGATGTTGA_1',
#               'GATCATGTCATGAGTC_1',
#               'GATGAGGTCAGAGTTC_1',
#               'GATGCTAAGCTGGTGA_1',
#               'GATGCTAGTCGGCACT_1',
#               'GATGGAGAGGCTCTAT_1',
#               'GATTGGTCAGTTGAAA_1',
#               'GATTTCTAGAGGCGTT_1',
#               'GCACATACATAACCCA_1',
#               'GCACGTGTCATGAGAA_1',
#               'GCAGCTGTCGATTGAC_1',
#               'GCAGGCTTCTTCGTGC_1',
#               'GCATCGGTCGTCGGGT_1',
#               'GCATTAGAGCAGGCAT_1',
#               'GCCAGTGCAGAATGTA_1',
#               'GCCATTCCATGGAAGC_1',
#               'GCCATTCTCCTCCACA_1',
#               'GCCCAGACACACGGAA_1',
#               'GCCCGAACATTAGGAA_1',
#               'GCCGATGAGGCATTTC_1',
#               'GCCGTGATCTGTTCAT_1',
#               'GCGAGAAAGCCATATC_1',
#               'GCGAGAATCACGACTA_1',
#               'GCGGAAAGTCGTACTA_1',
#               'GCGGAAATCATCCCGT_1',
#               'GCGGATCTCATGAGTC_1',
# ...
#               'TGTACAGTCTGACAGT_3',
#               'TGTGAGTGTCCCTGAG_3',
#               'TGTGATGAGCAATAGT_3',
#               'TGTGATGAGCGATCGA_3',
#               'TGTGATGCACACAGAG_3',
#               'TGTTCATCAAAGGAGA_3',
#               'TGTTCATCAATTGCGT_3',
#               'TTAATCCAGTGCCTCG_3',
#               'TTAATCCGTGCGTTTA_3',
#               'TTACCGCAGCGACTAG_3',
#               'TTACGCCAGAGAGAAC_3',
#               'TTACGCCAGGCGAACT_3',
#               'TTACGCCTCCCAAGCG_3',
#               'TTACGTTCAATAGGAT_3',
#               'TTACTGTGTGATACTC_3',
#               'TTAGGCAGTTGCGGAA_3',
#               'TTAGTCTTCGCTACAA_3',
#               'TTATTGCGTGACACAG_3',
#               'TTATTGCGTGCCGTTG_3',
#               'TTCAATCGTTTACGAC_3',
#               'TTCATGTGTATTGACC_3',
#               'TTCCAATCACCTGCTT_3',
#               'TTCCTTCCAATGAAAC_3',
#               'TTCTAGTTCGCGCCAA_3',
#               'TTCTGTAAGCCTTGAT_3',
#               'TTGATGGGTCTTTCAT_3',
#               'TTGCATTGTTATCCAG_3',
#               'TTGGGTATCCAACTAG_3',
#               'TTGGGTATCGGCATCG_3',
#               'TTGTGTTTCTTTCCGG_3',
#               'TTGTTCACACGCTGAC_3',
#               'TTTACTGAGGTAGTAT_3',
#               'TTTAGTCGTCCAGTTA_3',
#               'TTTCATGAGAGTGAAG_3',
#               'TTTCCTCCACAATCTG_3',
#               'TTTGTTGGTAACAGTA_3',
#               'TTTGTTGTCGTCCATC_3'],
#              25.0: ['AAAGAACAGGTCACCC-1_4',
#               'AACGTCAGTTCAGTAC-1_4',
#               'AAGATAGTCAAGCCGC-1_4',
#               'AAGCCATCACACGGTC-1_4',
#               'AAGCGAGGTGCCTGAC-1_4',
#               'AAGGTAATCTCATGCC-1_4',
#               'AATGAAGTCCGAAATC-1_4',
#               'ACACGCGCAGTGCCTG-1_4',
#               'ACCTACCAGGGATGTC-1_4',
#               'ACCTACCTCTGGGCAC-1_4',
#               'ACCTGAAAGACCTCCG-1_4',
#               'ACGTCCTGTGTGATGG-1_4',
#               'ACTGATGGTAGTGGCA-1_4',
#               'AGAGCCCCATCCGGCA-1_4',
#               'AGCCAGCCACTGGATT-1_4',
#               'AGGGAGTTCATCACTT-1_4',
#               'AGGGAGTTCTAAGCCA-1_4',
#               'AGGTAGGGTAACCCGC-1_4',
#               'AGGTTACAGGCCTTCG-1_4',
#               'AGGTTGTAGGCGATAC-1_4',
#               'AGTCTCCCACCTGTCT-1_4',
#               'AGTTCCCGTAGAGTTA-1_4',
#               'ATAGAGACAGGAGGTT-1_4',
#               'ATCACAGGTTGCCATA-1_4',
#               'ATCACGACAGTTCTAG-1_4',
#               'ATCATTCGTCCGGATC-1_4',
#               'ATCCATTCATAGATCC-1_4',
#               'ATCCATTTCCTGTTGC-1_4',
#               'ATGGATCTCTTAATCC-1_4',
#               'ATGGGTTAGATGTTCC-1_4',
#               'ATTACCTGTCTGTGCG-1_4',
#               'ATTCACTAGCTTACGT-1_4',
#               'ATTCTACTCCTCACTG-1_4',
#               'CAACAACAGACGAAGA-1_4',
#               'CAGGGCTTCCATCAGA-1_4',
#               'CAGTTAGTCACCTCGT-1_4',
#               'CAGTTAGTCTCTGACC-1_4',
#               'CATAAGCGTCATAACC-1_4',
#               'CATACTTAGATGCTGG-1_4',
#               'CATACTTTCGGCTCTT-1_4',
#               'CATTCATTCGGACAAG-1_4',
#               'CCACGAGTCATGCCAA-1_4',
#               'CCCGAAGTCATTTACC-1_4',
#               'CCCTAACAGTCGAAGC-1_4',
#               'CCGGACATCTCCCTAG-1_4',
#               'CCTAAGAAGTGGTGAC-1_4',
#               'CCTCCAACAGATTTCG-1_4',
#               'CGATCGGGTACTCCGG-1_4',
#               'CGATGGCCAGAGCCCT-1_4',
#               'CGATGGCTCGCAGATT-1_4',
#               'CGCAGGTTCCCTTCCC-1_4',
#               'CGCCATTAGCCTCAGC-1_4',
#               'CGCGTGAAGTCGCCAC-1_4',
#               'CGGAGAAGTTTACGAC-1_4',
#               'CGGGTCAAGCCTCAAT-1_4',
#               'CGTGCTTGTCACGCTG-1_4',
#               'CGTGTCTCAAACCATC-1_4',
#               'CGTTCTGTCTCGCAGG-1_4',
#               'CTACAGAAGAGGTTAT-1_4',
#               'CTACATTGTTTAGAGA-1_4',
#               'CTCACTGGTTCCGTTC-1_4',
#               'CTCAGAACATTGGATC-1_4',
#               'CTCCATGGTAGCTTAC-1_4',
#               'CTCTCAGCAATCACGT-1_4',
#               'CTCTCAGCAGTGTACT-1_4',
#               'CTGAGCGTCGGATTAC-1_4',
#               'CTGATCCAGTTCCTGA-1_4',
#               'CTGTAGATCATCGCCT-1_4',
#               'CTTCTCTGTAAGGTCG-1_4',
#               'GAAGCGAGTTGCATGT-1_4',
#               'GACAGCCAGTCTAACC-1_4',
#               'GACAGCCTCTAGTACG-1_4',
#               'GACTATGAGGTCCCTG-1_4',
#               'GAGACTTCAAGGTTGG-1_4',
#               'GAGACTTCAATTCACG-1_4',
#               'GAGATGGTCACTACTT-1_4',
#               'GAGCCTGTCCGCCTAT-1_4',
#               'GATTTCTTCTTGGAAC-1_4',
#               'GCATTAGGTGTTGATC-1_4',
#               'GCTCAAACAATGAGCG-1_4',
#               'GCTTTCGCATGACCCG-1_4',
#               'GGAGAACAGACTACGG-1_4',
#               'GGTGAAGAGTAGATCA-1_4',
#               'GTAGGTTAGTATGGAT-1_4',
#               'GTCATTTCAGAGGCAT-1_4',
#               'GTCCTCACACGCTATA-1_4',
#               'GTCGTTCTCCGTAATG-1_4',
#               'GTGGAGAAGAAACTGT-1_4',
#               'GTGGCGTCATTCACAG-1_4',
#               'GTGTTAGGTTATCTGG-1_4',
#               'GTGTTCCCACAAAGTA-1_4',
#               'GTTACAGTCTCCCAAC-1_4',
#               'GTTACGAAGGTGCTTT-1_4',
#               'GTTAGACAGGTGGGTT-1_4',
#               'GTTGAACGTGACAACG-1_4',
#               'GTTGAACTCTCACCCA-1_4',
#               'GTTGTCCAGATACCAA-1_4',
#               'GTTTACTTCACGAACT-1_4',
#               'TAAGCCACAGACTGCC-1_4',
#               'TACTGCCGTGAGTAAT-1_4',
#               'TAGACTGAGTACAGCG-1_4',
#               'TATTCCACAGAGTGTG-1_4',
#               'TATTCCACATGCCGGT-1_4',
#               'TATTGCTGTCGTGGTC-1_4',
#               'TCAGCAACAAACGTGG-1_4',
#               'TCAGTCCTCCCTTTGG-1_4',
#               'TCATGAGAGTTCACTG-1_4',
#               'TCATTACGTAATGCTC-1_4',
#               'TCATTACTCCCGTTGT-1_4',
#               'TCCATCGTCACACCGG-1_4',
#               'TCCGGGATCTCAGAAC-1_4',
#               'TCCTCTTAGGATTCAA-1_4',
#               'TCCTCTTGTGACCTGC-1_4',
#               'TCCTCTTTCTCCACTG-1_4',
#               'TCGTGCTGTGGTTTGT-1_4',
#               'TCTAACTGTAACTTCG-1_4',
#               'TCTATACCAGCCCAGT-1_4',
#               'TCTCACGCAAGTTCCA-1_4',
#               'TCTCAGCGTTGACTAC-1_4',
#               'TCTCTGGGTCGGCACT-1_4',
#               'TCTCTGGGTGGTATGG-1_4',
#               'TCTCTGGTCGGTCTAA-1_4',
#               'TCTGCCACAAAGCTAA-1_4',
#               'TGAATGCGTCTGTAAC-1_4',
#               'TGCACGGAGTGTAGTA-1_4',
#               'TGCATCCCACCCTGTT-1_4',
#               'TGCATCCCACTCACTC-1_4',
#               'TGCGGCAAGCTTTGTG-1_4',
#               'TGCGGGTCACGAGGAT-1_4',
#               'TGCTTCGAGCGTCTGC-1_4',
#               'TGGAACTGTCTGTGCG-1_4',
#               'TGGTACACAAGACCGA-1_4',
#               'TGTAAGCAGATACAGT-1_4',
#               'TGTAGACCAGTCGGAA-1_4',
#               'TGTGAGTTCTCAGTCC-1_4',
#               'TGTTACTAGCGATGAC-1_4',
#               'TGTTACTTCATGCTAG-1_4',
#               'TGTTTGTTCGTACACA-1_4',
#               'TTACCATCAAGATTGA-1_4',
#               'TTACCGCTCATAGGCT-1_4',
#               'TTATTGCAGTCTTCGA-1_4',
#               'TTCATGTGTCGAACGA-1_4',
#               'TTCTGTAAGATTGATG-1_4',
#               'TTTCAGTAGACGACGT-1_4',
#               'TTTGGTTTCTTTACAC-1_4'],
#              24.0: ['AACAAAGAGGACACTG-1_4',
#               'AACCAACGTGACTGAG-1_4',
#               'AACCATGCATTAAGCC-1_4',
#               'AACCTGAAGATTAGTG-1_4',
#               'AACCTTTGTGTGAGCA-1_4',
#               'AACGAAACATACCATG-1_4',
#               'AACTTCTCAAATCGGG-1_4',
#               'AAGGTAATCCGATCTC-1_4',
#               'ACAAAGAGTCTTACTT-1_4',
#               'ACAGAAAAGCTGACAG-1_4',
#               'ACATCCCTCAAGCTTG-1_4',
#               'ACCATTTTCGCTGCGA-1_4',
#               'ACCCAAATCCATATGG-1_4',
#               'ACCCTCATCGCAGTCG-1_4',
#               'ACCTGAATCCTCAGAA-1_4',
#               'ACGATCAGTTTCAGAC-1_4',
#               'ACGATGTAGCGTTGTT-1_4',
#               'ACGGTTACATGGGATG-1_4',
#               'ACGTAACGTGCGTCGT-1_4',
#               'ACTATGGCACGCGCTA-1_4',
#               'ACTATTCCATTGTAGC-1_4',
#               'ACTGATGCAGCTTTCC-1_4',
#               'AGACAGGCAGGAGGTT-1_4',
#               'AGCGCTGGTCGTGTTA-1_4',
#               'AGCTACAAGTAGCTCT-1_4',
#               'AGGAATACAGATCACT-1_4',
#               'AGGATCTGTGCATTAC-1_4',
#               'AGGTAGGAGCTAGAGC-1_4',
#               'AGGTGTTCAATCTGCA-1_4',
#               'AGGTTACTCCGGCAAC-1_4',
#               'AGTAACCGTGCCTAAT-1_4',
#               'ATCATTCGTCAGTCCG-1_4',
#               'ATCGATGTCTGCCTCA-1_4',
#               'ATCGGATTCAAGAGGC-1_4',
#               'ATCGGCGAGTACGTCT-1_4',
#               'ATCGTGAGTAGCTTTG-1_4',
#               'ATGAAAGGTATCGCAT-1_4',
#               'ATGCATGGTGGGCTCT-1_4',
#               'ATGCCTCAGAGCATCG-1_4',
#               'ATGCGATGTATGAAGT-1_4',
#               'ATTCACTAGAGCCATG-1_4',
#               'ATTCCATAGCATTTCG-1_4',
#               'ATTTACCTCGCTGTTC-1_4',
#               'CAACGATTCATCAGTG-1_4',
#               'CAACGATTCGAGCTGC-1_4',
#               'CAAGAGGAGTGAGTTA-1_4',
#               'CAAGGGACAGGCGTTC-1_4',
#               'CAATGACAGCTCCGAC-1_4',
#               'CACGGGTCACGGGTAA-1_4',
#               'CACTAAGTCAAACTGC-1_4',
#               'CAGGGCTAGGGATCGT-1_4',
#               'CAGGGCTCAGTTCTAG-1_4',
#               'CAGTTAGAGGGATCGT-1_4',
#               'CATGAGTCAACCCTAA-1_4',
#               'CATGCAATCCTACGGG-1_4',
#               'CATGCTCTCTGCGGGT-1_4',
#               'CATGGTATCCTTTGAT-1_4',
#               'CATTGCCCAGGACAGT-1_4',
#               'CCAAGCGAGTTCTACG-1_4',
#               'CCACACTCAAATGATG-1_4',
#               'CCACGTTAGCCTAGGA-1_4',
#               'CCATCACTCTTAGGAC-1_4',
#               'CCCAACTTCGAACACT-1_4',
#               'CCTCATGTCTGTGTGA-1_4',
#               'CCTCCTCGTTTGGAGG-1_4',
#               'CGAAGGACATCCAATG-1_4',
#               'CGAATTGAGAGGACTC-1_4',
#               'CGAATTGAGTGGATAT-1_4',
#               'CGATCGGAGTGAGGTC-1_4',
#               'CGATGGCAGCAGTAAT-1_4',
#               'CGATGGCTCCAATCCC-1_4',
#               'CGGACACAGAGGTCAC-1_4',
#               'CGGAGAAGTCGTTTCC-1_4',
#               'CGTAAGTAGTAAGGGA-1_4',
#               'CGTGATACATAGAATG-1_4',
#               'CGTGCTTAGCAGGCTA-1_4',
#               'CTCAATTGTACATACC-1_4',
#               'CTCACTGAGTCGAGGT-1_4',
#               'CTCACTGCACTACCCT-1_4',
#               'CTGTCGTGTGCGGATA-1_4',
#               'CTTCCGAAGCTAAATG-1_4',
#               'CTTCCGACAGGGTTGA-1_4',
#               'CTTGAGAAGAGGTTAT-1_4',
#               'CTTGATTGTGTTGACT-1_4',
#               'CTTTCAAAGTGACCTT-1_4',
#               'GAATCGTGTTCTATCT-1_4',
#               'GACACGCCATGACTTG-1_4',
#               'GAGAAATTCCCAGGAC-1_4',
#               'GAGATGGCATTGGCAT-1_4',
#               'GAGGCCTCAACGGCTC-1_4',
#               'GAGTCATCACACACGC-1_4',
#               'GATGACTTCAATGCAC-1_4',
#               'GCATCGGCAGGGCTTC-1_4',
#               'GCCAGTGTCCGCATAA-1_4',
#               'GCCATGGTCAGAGCAG-1_4',
#               'GCCCGAACATTCGGGC-1_4',
#               'GCTGGGTGTGGCTTAT-1_4',
#               'GGACGTCCATTGGGAG-1_4',
#               'GGAGAACTCAGTCAGT-1_4',
#               'GGAGGATAGGATGCGT-1_4',
#               'GGGTCTGGTGCAACGA-1_4',
#               'GGTTCTCTCTCCAATT-1_4',
#               'GGTTGTATCTAGTGAC-1_4',
#               'GTAACACGTCCCTCAT-1_4',
#               'GTAGGTTTCATATGGC-1_4',
#               'GTATTTCAGTATTAGG-1_4',
#               'GTCACGGCACTTCATT-1_4',
#               'GTCATTTAGAGGTGCT-1_4',
#               'GTCCACTGTGTTCGTA-1_4',
#               'GTCTCACTCCCGAATA-1_4',
#               'GTGACGCAGCGGACAT-1_4',
#               'GTGGCGTGTGGATGAC-1_4',
#               'GTGGGAAGTGCACAAG-1_4',
#               'GTGTAACGTAGAGGAA-1_4',
#               'GTGTAACTCAAACGTC-1_4',
#               'GTGTGGCTCTGGGAGA-1_4',
#               'GTTAGACTCGTGGGAA-1_4',
#               'GTTGTAGAGTCCGTCG-1_4',
#               'TAAGCACCAAGATGGC-1_4',
#               'TACAACGAGACAAGCC-1_4',
#               'TACCCACGTTAGGAGC-1_4',
#               'TACCCGTAGTATAGGT-1_4',
#               'TACGGGCAGCCGAACA-1_4',
#               'TACTTACTCCATTGCC-1_4',
#               'TAGATCGGTGCGCTCA-1_4',
#               'TATGTTCCAGTATTCG-1_4',
#               'TATTGCTCATCCAACA-1_4',
#               'TCATACTTCTTGAACG-1_4',
#               'TCATCATTCTGACAGT-1_4',
#               'TCATCCGGTCCAGCAC-1_4',
#               'TCATGGAAGCGATTCT-1_4',
#               'TCATTCAGTTTCTTAC-1_4',
#               'TCCACGTCAAGTGGCA-1_4',
#               'TCCACGTCAGCGTAGA-1_4',
#               'TCCATGCTCCTACTGC-1_4',
#               'TCCGATCAGAGTGAAG-1_4',
#               'TCCGATCTCGAGTCTA-1_4',
#               'TCCGTGTTCTCTGCTG-1_4',
#               'TCCTTTCTCGTTCGCT-1_4',
#               'TCGACCTCACTTGAAC-1_4',
#               'TCGTGCTTCGTCTACC-1_4',
#               'TCTGCCACACCAGCTG-1_4',
#               'TGACAGTAGGTCCAGA-1_4',
#               'TGACAGTCAACCCTCT-1_4',
#               'TGAGACTCATGGAATA-1_4',
#               'TGATGGTTCTTGATTC-1_4',
#               'TGCAGTATCGGCGATC-1_4',
#               'TGCTGAAGTCGTACTA-1_4',
#               'TGGTAGTGTGGTAATA-1_4',
#               'TGTAACGAGGTTAAAC-1_4',
#               'TGTAGACGTATACAGA-1_4',
#               'TGTTCCGAGTGGTTCT-1_4',
#               'TTACAGGCAGAAATTG-1_4',
#               'TTATTGCAGTCGGCAA-1_4',
#               'TTATTGCTCCATTGTT-1_4',
#               'TTCCAATGTGAGATTA-1_4',
#               'TTCCTTCAGGGTACGT-1_4',
#               'TTCGCTGAGCAATAAC-1_4',
#               'TTCGGTCAGCGGCTCT-1_4',
#               'TTCGGTCTCTGAATCG-1_4',
#               'TTGAACGAGAATAGTC-1_4',
#               'TTGCATTCAGATTCGT-1_4',
#               'TTGGGCGAGAGTCCGA-1_4',
#               'TTTACGTGTCTAGGCC-1_4',
#               'TTTAGTCCAAGACGGT-1_4',
#               'TTTAGTCGTAGCGTCC-1_4'],
#              23.0: ['AAGTACCTCCGAGCTG-1_4',
#               'AATGACCGTGACTCGC-1_4',
#               'AATGGAACATGACACT-1_4',
#               'AATTCCTTCGAGGCAA-1_4',
#               'ACAAAGATCCATTTGT-1_4',
#               'ACAAGCTTCTGGCTGG-1_4',
#               'ACACCAAAGTGTAGTA-1_4',
#               'ACCGTTCTCTCTCGAC-1_4',
#               'ACGCACGCAAGCGGAT-1_4',
#               'ACGGTCGGTGCCCACA-1_4',
#               'ACTATTCTCTACGCGG-1_4',
#               'ACTTCGCTCGCATTGA-1_4',
#               'ACTTTCATCCACGAAT-1_4',
#               'AGCATCAAGAAGCGAA-1_4',
#               'AGGTTGTAGTCACTAC-1_4',
#               'ATCGGCGTCTACGGGC-1_4',
#               'ATGAGGGCACGTCTCT-1_4',
#               'ATGGATCCATGTTTGG-1_4',
#               'ATTCAGGGTCTGTTAG-1_4',
#               'ATTCATCAGTCATGCT-1_4',
#               'ATTTACCGTGGATCAG-1_4',
#               'CAACCAAGTCTAGATC-1_4',
#               'CAACCTCAGCACTCTA-1_4',
#               'CAAGAGGCACACAGCC-1_4',
#               'CAGAGCCTCGAGCACC-1_4',
#               'CAGTGCGAGAGCCGAT-1_4',
#               'CATCAAGCACATTCTT-1_4',
#               'CCTCATGTCGGTCATA-1_4',
#               'CGACAGCCAATAACCC-1_4',
#               'CGAGGCTGTTTCCATT-1_4',
#               'CGGAGAAAGGATATAC-1_4',
#               'CGGGCATTCACTCCGT-1_4',
#               'CGGGTCAAGGCCTGCT-1_4',
#               'CTAACTTCACAGAGAC-1_4',
#               'CTAACTTGTCCTTAAG-1_4',
#               'CTCAACCTCTTACCAT-1_4',
#               'CTCAATTGTGTCCTAA-1_4',
#               'CTGTATTGTGACTATC-1_4',
#               'CTTCAATTCACTCTTA-1_4',
#               'GACATCATCTGTCCCA-1_4',
#               'GCAACATAGGCATGGT-1_4',
#               'GCTACCTAGCGTCAAG-1_4',
#               'GCTGCAGAGGTTACCT-1_4',
#               'GGAGATGCACGGAAGT-1_4',
#               'GGATGTTCAGAAACCG-1_4',
#               'GTAAGTCCAACCGGAA-1_4',
#               'GTCTACCAGTCAGGGT-1_4',
#               'GTCTAGAGTAGGTGCA-1_4',
#               'GTCTCACTCCGTGTGG-1_4',
#               'GTGAGTTTCCAGGACC-1_4',
#               'GTGATGTTCCCGAGGT-1_4',
#               'GTTCTATAGTTCGCAT-1_4',
#               'TACACCCGTACAGCGA-1_4',
#               'TACGGGCGTGTTGAGG-1_4',
#               'TACGTCCTCGTCCATC-1_4',
#               'TAGACCATCTACCAGA-1_4',
#               'TAGGTACGTTGGTACT-1_4',
#               'TATCGCCCATGTGGCC-1_4',
#               'TCATATCAGCTTAGTC-1_4',
#               'TCCCAGTAGCCTCTTC-1_4',
#               'TCCCATGGTGCCAAGA-1_4',
#               'TCCTTTCGTGAATATG-1_4',
#               'TCGTAGAAGTGACCTT-1_4',
#               'TGATGGTCAACGACTT-1_4',
#               'TGCATCCTCTGGGTCG-1_4',
#               'TGGGAGAAGCCTAGGA-1_4',
#               'TGGGAGAAGGTAAGAG-1_4',
#               'TGTGCGGTCTTTACAC-1_4',
#               'TGTTCATGTCTTGAAC-1_4',
#               'TTAGGGTAGGACAACC-1_4',
#               'TTCAATCCATGATAGA-1_4',
#               'TTCTCTCCATCGCTCT-1_4',
#               'TTTCCTCCAGGATTCT-1_4',
#               'TTTGGAGAGCCGTTGC-1_4']})

# %%
oligodendro = oligodendro.T

# %%
pred_freqs
# Out:
#              3.0       4.0       5.0       6.0       8.0       9.0       10.0  \
# Dpyd     0.000664  0.000726  0.000788  0.000850  0.000973  0.001035  0.001097
# Ogdhl    0.000287  0.000370  0.000453  0.000536  0.000701  0.000784  0.000867
# Abca8a   0.007595  0.007774  0.007952  0.008131  0.008488  0.008666  0.008845
# Gstm6    0.001698  0.001761  0.001824  0.001886  0.002012  0.002074  0.002137
# Ccdc136  0.000880  0.000935  0.000990  0.001045  0.001155  0.001210  0.001265
# ...           ...       ...       ...       ...       ...       ...       ...
# Lmo7     0.000176  0.000168  0.000160  0.000153  0.000138  0.000130  0.000122
# Fmo5     0.000344  0.000359  0.000374  0.000389  0.000419  0.000435  0.000450
# Gm4221   0.001933  0.001859  0.001785  0.001711  0.001564  0.001490  0.001416
# Sag      0.000056  0.000066  0.000076  0.000087  0.000108  0.000118  0.000128
# Pcdhb18  0.000376  0.000400  0.000423  0.000447  0.000495  0.000519  0.000542
#
#              12.0      14.0      16.0      18.0      20.0      21.0      22.0  \
# Dpyd     0.001220  0.001344  0.001467  0.001590  0.001714  0.001776  0.001837
# Ogdhl    0.001032  0.001198  0.001364  0.001529  0.001695  0.001778  0.001861
# Abca8a   0.009202  0.009559  0.009916  0.010273  0.010630  0.010809  0.010988
# Gstm6    0.002262  0.002388  0.002513  0.002639  0.002764  0.002827  0.002890
# Ccdc136  0.001375  0.001485  0.001595  0.001705  0.001815  0.001870  0.001925
# ...           ...       ...       ...       ...       ...       ...       ...
# Lmo7     0.000107  0.000092  0.000077  0.000062  0.000046  0.000039  0.000031
# Fmo5     0.000480  0.000510  0.000541  0.000571  0.000601  0.000616  0.000632
# Gm4221   0.001269  0.001121  0.000973  0.000826  0.000678  0.000604  0.000531
# Sag      0.000149  0.000170  0.000191  0.000211  0.000232  0.000243  0.000253
# Pcdhb18  0.000590  0.000638  0.000685  0.000733  0.000781  0.000804  0.000828
#
#              23.0      24.0      25.0      29.0
# Dpyd     0.001899  0.001961  0.002023  0.002270
# Ogdhl    0.001944  0.002026  0.002109  0.002441
# Abca8a   0.011166  0.011345  0.011523  0.012237
# Gstm6    0.002952  0.003015  0.003078  0.003328
# Ccdc136  0.001980  0.002035  0.002090  0.002310
# ...           ...       ...       ...       ...
# Lmo7     0.000024  0.000016  0.000008  0.000001
# Fmo5     0.000647  0.000662  0.000677  0.000738
# Gm4221   0.000457  0.000383  0.000309  0.000014
# Sag      0.000263  0.000274  0.000284  0.000326
# Pcdhb18  0.000852  0.000876  0.000900  0.000995
#
# [100 rows x 18 columns]

# %%
oli_cell_sums[cell]
# Out:
# 21

# %%
outcome = defaultdict(list)
freq_probs = defaultdict(list)
## loop over each age group in pred_freqs
for age in pred_freqs:
    cell_group = oligodendro[oli_age_dict[age]]
    for cell in cell_group:
        _lambda = pred_freqs * oli_cell_sums[cell] # frequency of that gene expression * counts of all genes in that cell
        prob = poisson.pmf(np.array(cell_group[cell]).reshape(-1,1), _lambda)
        max_value = np.log(prob)
        max_value[max_value == -inf] = 0
        temp = np.sum(max_value, axis = 0).reshape(1,-1)
#         print("sum of loglikelihood: ")
#         display(pd.DataFrame(temp, columns = age_groups))
#         print(np.argmax(np.sum(np.log(prob), axis = 0)))
        max_value = train_ages[np.argmax(np.sum(max_value, axis = 0))]
        freq_probs[age].append(np.sum(np.log(prob), axis = 0))
        outcome[age].append(max_value[0])
#         print("predicted_result: ", max_value[0], " true_value: ", cell)

# %%
x = [int(inner) for outer in list(outcome.values()) for inner in outer]
y = []
for key in list(outcome.keys()):
    y.append(len(outcome[key]) * [key])

# %%
len(x), len([inner for outer in y for inner in outer])
# Out:
# (5943, 5943)

# %%
from matplotlib.pyplot import figure
from adjustText import adjust_text
figure(figsize=(10, 4), dpi=80)
ax = sns.violinplot(x, [int(inner) for outer in y for inner in outer])
plt.ylabel("Predicted Age")
# plt.xlim(2,30)
# plt.ylim(2,30)
plt.xlabel("True Age")
# adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5))
plt.show()
# Out:
# /Users/charlotte/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.plot(list(outcome.keys()), accuracy, marker="o")
plt.title("Accuracy Change")
plt.ylim(0.0,1.0)
plt.xticks(list(outcome.keys()))
plt.show()

# %%
from matplotlib.pyplot import figure
from adjustText import adjust_text
figure(figsize=(6, 4), dpi=80)
plt.scatter(x, [int(inner) for outer in y for inner in outer])
# labels = zip(x,y)
# texts = []
# for x, y, s in zip(test["true"], test["predicted"], labels):
#     texts.append(plt.text(x, y, s, fontsize=8))
plt.ylabel("Predicted Age")
# plt.xlim(2,30)
# plt.ylim(2,30)
plt.xlabel("True Age")
# adjust_text(texts, arrowprops=dict(arrowstyle="-", color='k', lw=0.5))
plt.show()

# %%
accuracy = []
for key in outcome:
    accur = 0
    for value in outcome[key]:
        if value == key:
            accur += 1
    accuracy.append(accur / len(outcome[key]))

# %%
accuracy
# Out:
# [0.5878489326765188,
#  0.03453947368421053,
#  0.13505747126436782,
#  0.049145299145299144,
#  0.05964912280701754,
#  0.013986013986013986,
#  0.06333973128598848,
#  0.09418282548476455,
#  0.09523809523809523,
#  0.062111801242236024,
#  0.15,
#  0.04044117647058824,
#  0.03626943005181347,
#  0.026022304832713755,
#  0.05405405405405406,
#  0.0783132530120482,
#  0.11724137931034483,
#  0.4778761061946903]
